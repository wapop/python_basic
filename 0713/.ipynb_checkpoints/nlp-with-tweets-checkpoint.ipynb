# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# -*- coding: utf-8 -*-
# 코드 내부에 한글을 사용가능 하게 해주는 부분입니다.

import numpy
import tensorflow as tf
from numpy import array
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Flatten,Embedding


#주어진 문장을 '단어'로 토큰화 하기

#케라스의 텍스트 전처리와 관련한 함수중 text_to_word_sequence 함수를 불러 옵니다.
from tensorflow.keras.preprocessing.text import text_to_word_sequence

# %%
train = pd.read_csv('/kaggle/input/nlp-getting-started/train.csv')
test = pd.read_csv('/kaggle/input/nlp-getting-started/test.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-61722c9f8814> in <module>
# ----> 1 train = pd.read_csv('/kaggle/input/nlp-getting-started/train.csv')
#       2 test = pd.read_csv('/kaggle/input/nlp-getting-started/test.csv')
#
# C:\ANACONDA\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# C:\ANACONDA\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     446
#     447     # Create the parser.
# --> 448     parser = TextFileReader(fp_or_buf, **kwds)
#     449
#     450     if chunksize or iterator:
#
# C:\ANACONDA\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     878             self.options["has_index_names"] = kwds["has_index_names"]
#     879
# --> 880         self._make_engine(self.engine)
#     881
#     882     def close(self):
#
# C:\ANACONDA\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1112     def _make_engine(self, engine="c"):
#    1113         if engine == "c":
# -> 1114             self._engine = CParserWrapper(self.f, **self.options)
#    1115         else:
#    1116             if engine == "python":
#
# C:\ANACONDA\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1889         kwds["usecols"] = self.usecols
#    1890
# -> 1891         self._reader = parsers.TextReader(src, **kwds)
#    1892         self.unnamed_cols = self._reader.unnamed_cols
#    1893
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File /kaggle/input/nlp-getting-started/train.csv does not exist: '/kaggle/input/nlp-getting-started/train.csv'

# %%
train.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-3b77fa18a747> in <module>
# ----> 1 train.head()
#
# NameError: name 'train' is not defined

# %%
test.head()

# %%
print(train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-246f4ac0135d> in <module>
# ----> 1 print(train)
#
# NameError: name 'train' is not defined

# %%
train = train.drop('id',axis=1)
train = train.drop('keyword',axis=1)
train = train.drop('location',axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-f71b8b1f8f05> in <module>
# ----> 1 train = train.drop('id',axis=1)
#       2 train = train.drop('keyword',axis=1)
#       3 train = train.drop('location',axis=1)
#       4
#
# NameError: name 'train' is not defined

# %%
train = train.values
X_train = train[:,0]
Y_train = train[:,1]

# %%
print(Y_train)
# Out:
# [1 1 1 ... 1 1 1]

# %%
# 토큰화 함수를 이용해 전처리 하는 과정입니다.


token = Tokenizer()             # 토큰화 함수 지정
token.fit_on_texts(X_train)       # 토큰화 함수에 문장 적용

# %%
print("\n단어 카운트:\n", token.word_counts)
# Out:
# 단어 카운트:
#  OrderedDict([('our', 98), ('deeds', 2), ('are', 402), ('the', 3239), ('reason', 20), ('of', 1825), ('this', 478), ('earthquake', 49), ('may', 88), ('allah', 9), ('forgive', 2), ('us', 125), ('all', 259), ('forest', 66), ('fire', 245), ('near', 55), ('la', 22), ('ronge', 1), ('sask', 1), ('canada', 11), ('residents', 8), ('asked', 9), ('to', 1948), ("'shelter", 1), ('in', 1983), ("place'", 1), ('being', 89), ('notified', 1), ('by', 519), ('officers', 8), ('no', 266), ('other', 36), ('evacuation', 50), ('or', 206), ('shelter', 6), ('place', 25), ('orders', 11), ('expected', 15), ('13', 21), ('000', 4), ('people', 195), ('receive', 2), ('wildfires', 10), ('california', 114), ('just', 319), ('got', 113), ('sent', 13), ('photo', 43), ('from', 422), ('ruby', 1), ('alaska', 6), ('as', 330), ('smoke', 48), ('pours', 1), ('into', 174), ('a', 2195), ('school', 67), ('rockyfire', 4), ('update', 39), ('hwy', 10), ('20', 22), ('closed', 20), ('both', 27), ('directions', 1), ('due', 31), ('lake', 14), ('county', 38), ('cafire', 2), ('flood', 57), ('disaster', 154), ('heavy', 20), ('rain', 45), ('causes', 13), ('flash', 21), ('flooding', 49), ('streets', 8), ('manitou', 1), ('colorado', 16), ('springs', 5), ('areas', 10), ("i'm", 240), ('on', 859), ('top', 55), ('hill', 7), ('and', 1423), ('i', 1397), ('can', 159), ('see', 105), ('woods', 2), ("there's", 37), ('an', 249), ('emergency', 156), ('happening', 12), ('now', 225), ('building', 30), ('across', 20), ('street', 23), ('afraid', 5), ('that', 567), ('tornado', 35), ('is', 950), ('coming', 51), ('area', 47), ('three', 30), ('died', 28), ('heat', 47), ('wave', 35), ('so', 316), ('far', 28), ('haha', 20), ('south', 31), ('tampa', 4), ('getting', 55), ('flooded', 4), ('hah', 3), ('wait', 26), ('second', 25), ('live', 63), ('what', 195), ('am', 71), ('gonna', 43), ('do', 169), ('fvck', 1), ('raining', 4), ('florida', 6), ('tampabay', 1), ('18', 18), ('19', 7), ('days', 29), ("i've", 40), ('lost', 24), ('count', 3), ('bago', 2), ('myanmar', 18), ('we', 228), ('arrived', 8), ('damage', 55), ('bus', 37), ('80', 3), ('multi', 4), ('car', 92), ('crash', 118), ('breaking', 40), ("what's", 25), ('up', 328), ('man', 111), ('love', 101), ('fruits', 2), ('summer', 42), ('lovely', 8), ('my', 675), ('fast', 22), ('goooooooaaaaaal', 1), ('ridiculous', 4), ('london', 15), ('cool', 32), ('skiing', 1), ('wonderful', 5), ('day', 116), ('looooool', 1), ('way', 81), ("can't", 87), ('eat', 7), ('shit', 56), ('was', 386), ('nyc', 12), ('last', 83), ('week', 39), ('girlfriend', 6), ('cooool', 1), ('you', 792), ('like', 348), ('pasta', 2), ('end', 42), ('bbcmtd', 1), ('wholesale', 4), ('markets', 7), ('ablaze', 28), ('http', 4308), ('t', 4749), ('co', 4739), ('lhyxeohy6c', 1), ('always', 46), ('try', 19), ('bring', 17), ('metal', 13), ('rt', 111), ('yao1e0xngw', 1), ('africanbaze', 1), ('news', 198), ('nigeria', 5), ('flag', 21), ('set', 48), ('aba', 14), ('2nndbgwyei', 1), ('crying', 9), ('out', 273), ('for', 892), ('more', 217), ('me', 326), ('plus', 8), ('side', 23), ('look', 73), ('at', 538), ('sky', 15), ('night', 50), ('it', 565), ('qqsmshaj3n', 1), ('phdsquares', 1), ('mufc', 2), ("they've", 5), ('built', 6), ('much', 64), ('hype', 3), ('around', 40), ('new', 224), ('acquisitions', 2), ('but', 321), ('doubt', 5), ('they', 194), ('will', 258), ('epl', 1), ('season', 14), ('inec', 2), ('office', 12), ('abia', 2), ('3imaomknna', 1), ('barbados', 1), ('bridgetown', 1), ('jamaica', 5), ('\x89ûò', 39), ('two', 102), ('cars', 21), ('santa', 6), ('cruz', 10), ('\x89ûó', 26), ('head', 43), ('st', 33), ('elizabeth', 2), ('police', 141), ('superintende', 1), ('wdueaj8q4j', 1), ('lord', 21), ('d', 38), ('check', 47), ('these', 50), ('roi2nsmejj', 2), ('3tj8zjin21', 2), ('yduixefipe', 2), ('lxtjc87kls', 2), ('nsfw', 4), ('outside', 25), ("you're", 66), ('alive', 11), ('dead', 97), ('inside', 28), ('had', 111), ('awesome', 16), ('time', 115), ('visiting', 1), ('cfc', 2), ('ancop', 1), ('site', 27), ('thanks', 29), ('tita ...

# %%
print("\n문장 카운트: ", token.document_count)
# Out:
# 문장 카운트:  7613

# %%
print("\n각 단어가 몇개의 문장에 포함되어 있는가:\n", token.word_docs)
# Out:
# 각 단어가 몇개의 문장에 포함되어 있는가:
#  defaultdict(<class 'int'>, {'us': 118, 'the': 2403, 'our': 96, 'forgive': 2, 'earthquake': 43, 'all': 250, 'this': 460, 'deeds': 2, 'allah': 9, 'are': 377, 'may': 87, 'reason': 20, 'of': 1643, 'fire': 224, 'forest': 63, 'sask': 1, 'canada': 11, 'near': 54, 'la': 22, 'ronge': 1, 'shelter': 5, 'to': 1703, 'asked': 8, 'place': 25, 'residents': 7, 'expected': 15, 'orders': 11, 'other': 36, "'shelter": 1, 'no': 250, "place'": 1, 'in': 1789, 'notified': 1, 'being': 85, 'or': 199, 'officers': 7, 'by': 512, 'evacuation': 49, 'california': 112, '13': 20, 'people': 190, 'wildfires': 10, 'receive': 2, '000': 4, 'sent': 13, 'from': 409, 'as': 298, 'alaska': 6, 'photo': 43, 'got': 107, 'ruby': 1, 'into': 170, 'pours': 1, 'just': 309, 'school': 63, 'smoke': 47, 'a': 1786, 'closed': 20, 'county': 37, 'directions': 1, 'lake': 12, 'due': 31, 'hwy': 10, 'cafire': 2, 'rockyfire': 4, 'both': 26, '20': 22, 'update': 38, 'areas': 9, 'flash': 21, 'springs': 5, 'disaster': 133, 'streets': 8, 'manitou': 1, 'rain': 42, 'colorado': 15, 'flood': 57, 'flooding': 48, 'heavy': 20, 'causes': 13, "i'm": 215, 'on': 792, 'i': 1141, 'top': 54, 'and': 1282, 'hill': 5, 'see': 100, 'woods': 2, 'can': 153, 'street': 22, 'across': 20, 'happening': 12, "there's": 37, 'building': 30, 'now': 222, 'emergency': 151, 'an': 245, 'that': 531, 'coming': 51, 'afraid': 5, 'area': 45, 'tornado': 34, 'is': 865, 'heat': 45, 'wave': 35, 'three': 27, 'died': 28, 'far': 28, 'so': 294, 'am': 68, 'flooded': 4, 'live': 61, 'tampa': 3, 'haha': 20, 'second': 25, 'fvck': 1, 'hah': 3, 'gonna': 41, 'wait': 26, 'south': 30, 'getting': 54, 'what': 193, 'do': 161, 'count': 3, 'raining': 4, 'tampabay': 1, '18': 18, 'florida': 6, 'lost': 23, '19': 7, 'days': 29, "i've": 39, 'myanmar': 16, 'bago': 1, 'arrived': 8, 'we': 209, 'damage': 54, 'breaking': 40, 'car': 88, '80': 3, 'multi': 4, 'crash': 108, 'bus': 32, "what's": 25, 'up': 317, 'man': 105, 'fruits': 2, 'love': 93, 'lovely': 8, 'summer': 41, 'my': 598, 'fast': 21, 'goooooooaaaaaal': 1, 'ridiculous': 4, 'cool': 30, 'london': 14, 'skiing': 1, 'day': 109, 'wonderful': 5, 'looooool': 1, 'shit': 54, "can't": 83, 'eat': 7, 'way': 79, 'was': 351, 'nyc': 12, 'week': 39, 'last': 81, 'girlfriend': 5, 'cooool': 1, 'like': 331, 'pasta': 2, 'you': 624, 'end': 41, 'co': 3978, 'markets': 7, 'lhyxeohy6c': 1, 't': 3983, 'http': 3603, 'bbcmtd': 1, 'wholesale': 4, 'ablaze': 28, 'bring': 17, 'metal': 12, 'try': 19, 'rt': 106, 'yao1e0xngw': 1, 'always': 45, 'africanbaze': 1, '2nndbgwyei': 1, 'set': 48, 'news': 189, 'nigeria': 5, 'flag': 21, 'aba': 14, 'crying': 9, 'more': 213, 'me': 295, 'out': 265, 'for': 840, 'qqsmshaj3n': 1, 'side': 22, 'at': 516, 'sky': 13, 'it': 496, 'night': 48, 'plus': 8, 'look': 73, 'built': 3, 'doubt': 5, 'hype': 3, 'phdsquares': 1, 'will': 247, 'mufc': 2, 'they': 177, 'much': 61, 'new': 218, 'acquisitions': 2, 'but': 315, 'season': 14, "they've": 5, 'epl': 1, 'around': 40, 'inec': 2, 'office': 12, 'abia': 2, '3imaomknna': 1, 'santa': 6, 'bridgetown': 1, 'st': 31, 'elizabeth': 2, 'police': 128, 'two': 95, '\x89ûó': 26, 'superintende': 1, 'head': 42, 'jamaica': 5, 'wdueaj8q4j': 1, 'cars': 20, 'barbados': 1, '\x89ûò': 38, 'cruz': 10, 'lord': 21, 'd': 36, 'yduixefipe': 2, '3tj8zjin21': 2, 'nsfw': 4, 'check': 44, 'lxtjc87kls': 2, 'these': 49, 'roi2nsmejj': 2, "you're": 60, 'alive': 11, 'inside': 27, 'dead': 94, 'outside': 25, 'had': 107, 'site': 27, 'time': 112, 'vida': 2, 'ancop': 1, 'thanks': 28, 'care': 29, 'visiting': 1, 'cfc': 2, 'tita': 2, 'taking': 16, 'awesome': 14, 'soooo': 2, 'pumped': 1, 'southridgelife': 1, 'o9qknbfofx': 1, 'preaching': 1, 'with': 526, 'hotel': 5, 'not': 282, 'wanted': 19, 'chicago': 19, 'your': 252, 'know': 111, 'tiyulif5c6': 1, 'gained': 6, '3': 127, 'followers': 8, 'grow': 8, 'stats': 3, 'west': 24, 'thousands': 17, 'how': 187, 'alone': 18, 'vl5tbr3wbr': 1, 'burned': 39, 'tracklist': 1, 'leave': 28, 'perfect': 10, 'life': 90, 'have': 363, 'every': 56, "it's": 169, 'better': 34, 'least': 35, 'quite': 10, 'get ...

# %%
x = token.texts_to_sequences(X_train)

# %%
padded_x = pad_sequences(x, 100)

# %%
print("\n패딩 결과:\n", padded_x)
# Out:
# 패딩 결과:
#  [[    0     0     0 ...  4634    89    40]
#  [    0     0     0 ...  6954  6955  1404]
#  [    0     0     0 ...  1405    24  1106]
#  ...
#  [    0     0     0 ...     1     2  6913]
#  [    0     0     0 ...   131  2048   316]
#  [    0     0     0 ...     1     2 22700]]

# %%
word_size = len(token.word_index) +1

# %%
model = Sequential()
model.add(Embedding(word_size, 8, input_length=100))  #벡터로 만들어준다. 숫자값으로 바꿔준다.
model.add(Flatten())
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(optimizer='adam', loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
Y_train = Y_train.astype('float64')

# %%
model.fit(padded_x, Y_train, epochs=20)
# Out:
# Epoch 1/20
# 238/238 [==============================] - 1s 3ms/step - loss: 0.6542 - accuracy: 0.6161
# Epoch 2/20
# 238/238 [==============================] - 1s 2ms/step - loss: 0.5055 - accuracy: 0.7902
# Epoch 3/20
# 238/238 [==============================] - 1s 2ms/step - loss: 0.3613 - accuracy: 0.8683
# Epoch 4/20
# 238/238 [==============================] - 1s 2ms/step - loss: 0.2570 - accuracy: 0.9149
# Epoch 5/20
# 238/238 [==============================] - 1s 2ms/step - loss: 0.1815 - accuracy: 0.9459
# Epoch 6/20
# 238/238 [==============================] - 1s 3ms/step - loss: 0.1293 - accuracy: 0.9665
# Epoch 7/20
# 238/238 [==============================] - 1s 2ms/step - loss: 0.0948 - accuracy: 0.9796
# Epoch 8/20
# 238/238 [==============================] - 1s 2ms/step - loss: 0.0720 - accuracy: 0.9844
# Epoch 9/20
# 238/238 [==============================] - 1s 2ms/step - loss: 0.0566 - accuracy: 0.9890
# Epoch 10/20
# 238/238 [==============================] - 1s 2ms/step - loss: 0.0454 - accuracy: 0.9907
# Epoch 11/20
# 238/238 [==============================] - 1s 2ms/step - loss: 0.0379 - accuracy: 0.9911
# Epoch 12/20
# 238/238 [==============================] - 1s 2ms/step - loss: 0.0319 - accuracy: 0.9928
# Epoch 13/20
# 238/238 [==============================] - 1s 2ms/step - loss: 0.0277 - accuracy: 0.9934
# Epoch 14/20
# 238/238 [==============================] - 1s 2ms/step - loss: 0.0239 - accuracy: 0.9937
# Epoch 15/20
# 238/238 [==============================] - 1s 2ms/step - loss: 0.0213 - accuracy: 0.9945
# Epoch 16/20
# 238/238 [==============================] - 1s 2ms/step - loss: 0.0195 - accuracy: 0.9934
# Epoch 17/20
# 238/238 [==============================] - 1s 2ms/step - loss: 0.0174 - accuracy: 0.9942
# Epoch 18/20
# 238/238 [==============================] - 1s 2ms/step - loss: 0.0160 - accuracy: 0.9949
# Epoch 19/20
# 238/238 [==============================] - 1s 2ms/step - loss: 0.0147 - accuracy: 0.9953
# Epoch 20/20
# 238/238 [==============================] - 1s 2ms/step - loss: 0.0139 - accuracy: 0.9951

# %%
test = test.drop('id',axis=1)
test = test.drop('keyword',axis=1)
test = test.drop('location',axis=1)

test = test.values
X_test = test[:,0]

# %%
print(X_test)
# Out:
# ['Just happened a terrible car crash'
#  'Heard about #earthquake is different cities, stay safe everyone.'
#  'there is a forest fire at spot pond, geese are fleeing across the street, I cannot save them all'
#  ... 'Green Line derailment in Chicago http://t.co/UtbXLcBIuY'
#  'MEG issues Hazardous Weather Outlook (HWO) http://t.co/3X6RBQJHn3'
#  '#CityofCalgary has activated its Municipal Emergency Plan. #yycstorm']

# %%
token1 = Tokenizer()

# %%
token1.fit_on_texts(X_test)

# %%
y = token.texts_to_sequences(X_test)

# %%
padded_x_test = pad_sequences(y, 100)

# %%
token1.word_docs
# Out:
# defaultdict(int,
#             {'car': 36,
#              'terrible': 7,
#              'just': 126,
#              'crash': 47,
#              'happened': 13,
#              'a': 725,
#              'cities': 6,
#              'safe': 8,
#              'about': 93,
#              'stay': 10,
#              'different': 3,
#              'earthquake': 20,
#              'heard': 20,
#              'everyone': 16,
#              'is': 395,
#              'i': 451,
#              'fleeing': 1,
#              'pond': 3,
#              'street': 12,
#              'forest': 38,
#              'across': 7,
#              'the': 1010,
#              'cannot': 5,
#              'there': 63,
#              'geese': 1,
#              'spot': 8,
#              'at': 192,
#              'all': 103,
#              'them': 44,
#              'are': 183,
#              'fire': 101,
#              'save': 15,
#              'spokane': 1,
#              'apocalypse': 20,
#              'wildfires': 6,
#              'lighting': 2,
#              'in': 738,
#              'soudelor': 9,
#              'and': 529,
#              'typhoon': 21,
#              '28': 3,
#              'kills': 23,
#              'taiwan': 4,
#              'china': 6,
#              "it's": 87,
#              'shaking': 1,
#              "we're": 8,
#              'an': 104,
#              'arsenal': 2,
#              'show': 25,
#              "they'd": 1,
#              'more': 104,
#              'yesterday': 11,
#              'probably': 10,
#              'did': 26,
#              'life': 38,
#              'still': 50,
#              'eh': 3,
#              'than': 48,
#              'hey': 7,
#              'how': 94,
#              'you': 261,
#              'nice': 6,
#              'hat': 12,
#              'what': 74,
#              'off': 55,
#              'fuck': 16,
#              'cold': 8,
#              "don't": 55,
#              'like': 134,
#              'no': 117,
#              'do': 74,
#              'that': 202,
#              'nooooooooo': 1,
#              'me': 109,
#              'tell': 16,
#              'if': 107,
#              'awesome': 7,
#              'co': 1735,
#              'bbc': 12,
#              'irwqcezweu': 1,
#              't': 1739,
#              'out': 132,
#              'http': 1540,
#              "birmingham's": 1,
#              'wholesale': 1,
#              'birmingham': 2,
#              'news': 90,
#              'ablaze': 13,
#              'breaks': 3,
#              'market': 16,
#              'shorts': 1,
#              'sunkxssedharry': 1,
#              'for': 325,
#              'will': 105,
#              'race': 1,
#              'wear': 3,
#              'toke': 1,
#              'previouslyondoyintv': 1,
#              'makinwa\x89ûªs': 1,
#              'twitter': 10,
#              'sets': 6,
#              'crisis': 11,
#              'cmghxba2xi': 1,
#              'nigerian': 7,
#              'marriage': 1,
#              'yduixefipe': 1,
#              '3tj8zjin21': 1,
#              'nsfw': 2,
#              'check': 15,
#              'lxtjc87kls': 1,
#              'these': 20,
#              'roi2nsmejj': 1,
#              'personalities': 1,
#              'burners': 1,
#              'my': 269,
#              'psa': 3,
#              'techies': 1,
#              'follow': 9,
#              'splitting': 1,
#              'i\x89ûªm': 5,
#              'leone': 1,
#              'sierra': 1,
#              'world': 38,
#              'amp': 148,
#              'beware': 3,
#              'guap': 1,
#              'turban': 1,
#              'burning': 47,
#              'via': 105,
#              'by': 241,
#              'etsy': 1,
#              'diva': 2,
#              'hodwosamws': 1,
#              'man': 35,
#              'with': 204,
#              'opener': 1,
#              'he': 83,
#              'eye': 8,
#              'it': 239,
#              'song': 13,
#              'people': 80,
#              'smh': 10,
#              'diss': 2,
#              'run': 16,
#              '1': 55,
#              'not': 122,
#              'cyhitheprynce': 1,
#              'game': 22,
#              'thing': 18,
#              '2': 86,
#              'set': 18,
#              'take': 31,
#              'though': 18,
#              'old': 38,
#              'victim': 6,
#              'burn': 8,
#              'ablaze\x89û': 1,
#              'rape': 3,
#              'of': 703,
#              'injuries': 19,
#              'as': 138,
#              '16': 9,
#              'herself': 2,
#              'she': 22,
#              'dies': 4,
#              'uk8hnrboob': 1,
#              'died': 18,
#              'year': 39,
#              'girl': 18,
#              'setting': 4,
#              'myself': 11,
#              '6vme7p5xhc': 1,
#              'wer': 1,
#              'him': 31,
#              'wonder': 7,
#              'rite': 1,
#              'field': 5,
#              'day': 37,
#              'pole': 3,
#              'bins': 1,
#              'went': 14,
#              'hydro': 1,
#              'other': 28,
#              'front': 7,
#              'flames': 16,
#              'house': 32,
#              'ctvtoronto': 1,
#              'up': 131,
#              'was': 148,
#              'on': 351,
#              '2015': 33,
#              'radio': 7,
#              'aa5bjgwfdv': 1,
#              'puls': 1,
#              'pulsradio': 1,
#              'nowplaying': 4,
#              'alfons': 1,
#              'john': 7,
#              "'burning": 1,
#              'giant': 8,
#              'mayoral': 1,
#              'feet': 5,
#              "let's": 8,
#              'kass': 1,
#              '100': 12,
#              'builds': 2,
#              'kfo2mksn6y': 1,
#              'wooden': 1,
#              'city': 20,
#              'effigy': 1,
#              'hall': 1,
#              "rahm'": 1,
#              'tall': 2,
#              'hope': 24,
#              'philippaeilhart': 1,
#              'hurt': 4,
#              'her': 47,
#              'but': 111,
#              'eyes': 12,
#              'anger': 4,
#              'insulted': 1,
#              'dhublath': 1,
#              'accident': 36,
#              'to': 763,
#              'sl0oqn0vyr': 1,
#              'cranberry': 1,
#              'cleared': 2,
#              '18': 7,
#              'back': 37,
#              'traffic': 6,
#              'between': 9,
#              'pa': 3,
#              'slow': 2,
#              'eb': 1,
#              'paturnpike': 1,
#              'patp': 1,
#              'damn': 14,
#              'from': 188,
#              'your': 115,
#              'swear': 6,
#              'curling': 1,
#              'wand': 1,
#              'needs': 6,
#              'cuase': 1,
#              'away': 14,
#              'someone': 19,
#              'self': 14,
#              "i'm": 97,
#              'got': 45,
#              'prone': 1,
#              'love': 42,
#              'shit': 24,
#              'badging': 1,
#              'hate': 9,
#              'recorder': 2,
#              'dual': 1,
#              'history': 11,
#              'lens': 1,
#              'kkfasjv6cj': 1,
#              'camera': 5,
#              '3': 63,
#              'driving': 8,
#              'zeroedgeå¨': 1,
#              're': 5,
#              'camcorder': 1,
#              'vehicle': 6,
#              'large': 8,
#              'coincidence': 1,
#              'or': 85,
#              '7vg8df9ple': 1,
#              'unresolved': 1,
#              'secrets': 1,
#              'curse': 1,
#              'past': 20,
#              'a283': 1,
#              'kingston': 1,
#              'roadpol': 1,
#              'roundabout': 1,
#              'lewes': 1,
#              'rather': 3,
#              'near': 28,
#              'a27': 1,
#              'southe': 1,
#              'east': 6,
#              'manga': 1,
#              'anime': 1,
#              'pretend': 2,
#              'black': 29,
#              'become': 9,
#              'darker': 1,
#              'way': 31,
#              'genuine': 2,
#              'certain': 5,
#              'en': 3,
#              'can': 70,
#              'feel': 30,
#              'sakuma': 1,
#              'hei': 1,
#              'feeling': 5,
#              'us': 49,
#              'referral': 1,
#              '1800': 1,
#              '465': 1,
#              'medical': 8,
#              'call': 21,
#              'injured': 25,
#              'dogbite': 1,
#              'service': 23,
#              'slipandfall': 1,
#              '87332': 1,
#              '800': 1,
#              'legal': 2,
#              'disney': 4,
#              "there's": 11,
#              'bloody': 18,
#              'happen': 10,
#              'store': 4,
#              'guy': 13,
#              'has': 91,
#              'huge': 10,
#              'gauges': 1,
#              'working': 3,
#              'waiting': 9,
#              'ears': 6,
#              'construction': 3,
#              'his': 54,
#              'going': 45,
#              'robynjilllian': 1,
#              'teesha': 1,
#              'wlsdomteeths': 1,
#              'gonna': 23,
#              'come': 21,
#              'due': 22,
#              'currently': 7,
#              'junctions': 1,
#              '10': 24,
#              'mins': 5,
#              'lwi3prba31': 1,
#              'northbound': 1,
#              'c': 11,
#              'm42': 1,
#              'j3': 1,
#              'delays': 3,
#              'j3a': 1,
#              'p': 19,
#              'soembie': 1,
#              'this': 210,
#              'daveoshry': 1,
#              'dave': 1,
#              'so': 108,
#              'jelly': 1,
#              'week': 19,
#              'would': 72,
#              'super': 11,
#              'say': 32,
#              'be': 176,
#              'met': 4,
#              'police': 53,
#              'block': 9,
#              'se': 4,
#              'gresham': 3,
#              'ter': 1,
#              'hit': 13,
#              'pdx911': 3,
#              'pg15000044357': 1,
#              'vista': 2,
#              '500': 2,
#              '35': 5,
#              'qhmxuljsx9': 1,
#              'calum5sos': 1,
#              'grì': 1,
#              'paraplegic': 1,
#              'training': 7,
#              'donate': 4,
#              'nberg': 1,
#              '6mpnycl8pk': 1,
#              'vaulter': 1,
#              'spread': 2,
#              'kira': 1,
#              'please': 25,
#              'left': 8,
#              'word': 5,
#              'indoor': 1,
#              'trampoline': 1,
#              'share': 7,
#              'aftershock': 14,
#              'our': 45,
#              'new': 100,
#              'park': 21,
#              'page': 3,
#              'ugxhherrxs': 1,
#              'fall': 19,
#              'opening': 4,
#              'tem': 1,
#              'que': 2,
#              'bxckylynch': 1,
#              'las': 2,
#              'roh': 1,
#              'vegas': 3,
#              'foi': 1,
#              'bay': 5,
#              'procura': 1,
#              'pirate': 1,
#              'schoolboy': 1,
#              'schella': 1,
#              'loud': 18,
#              'sexism': 1,
#              'jqlzua6yzq': 1,
#              'far': 16,
#              'too': 27,
#              'excision': 1,
#              'original': 3,
#              'firebeatz': 1,
#              'remix': 2,
#              'dear': 6,
#              'skism': 1,
#              'mix': 3,
#              '\x89ûò': 22,
#              'dance': 4,
#              'ices\x89û': 3,
#              'icemoon': 3,
#              'dubstep': 3,
#              'dnb': 3,
#              'ir': 4,
#              '83joo0xk29': 2,
#              'edm': 4,
#              'thyzomvwu0': 2,
#              'trapmusic': 3,
#              '320': 3,
#              'djicemoon': 3,
#              'laco': 1,
#              'were': 52,
#              'fd': 1,
#              '1st': 5,
#              'chief': 5,
#              "'when": 2,
#              "'": 62,
#              'we': 98,
#              'collins': 4,
#              'nepal': 6,
#              "int'l": 1,
#              'team': 9,
#              'last': 44,
#              'responders': 24,
#              'ggmvzt58ve': 1,
#              'grpef7yawg': 1,
#              "wish'": 1,
#              'saying': 8,
#              'start': 12,
#              'unknown': 2,
#              "will'": 1,
#              'stop': 31,
#              "'i": 12,
#              'want': 29,
#              'afford': 2,
#              'because': 36,
#              'bands': 1,
#              'listen': 12,
#              'october': 1,
#              'go': 44,
#              "can't": 33,
#              'gradschoolapps': 1,
#              'nxt': 1,
#              'yet': 13,
#              "'we": 5,
#              'scars': 1,
#              'engtl5wrgp': 1,
#              'bond': 1,
#              'edward': 1,
#              'hiroshima': 46,
#              'living': 10,
#              'https': 205,
#              'ecy4u623no': 1,
#              'david': 7,
#              'victory': 3,
#              "'there": 1,
#              'dwight': 1,
#              'bargain': 3,
#              'eisenhower': 1,
#              'basement': 3,
#              'prices': 1,
#              'bo2': 1,
#              'bo3': 1,
#              'same': 12,
#              'competitive': 1,
#              'maps': 3,
#              'had': 48,
#              'invahnwetrust': 1,
#              'best': 35,
#              'imo': 1,
#              'uxyzyaygty': 1,
#              'copper': 1,
#              'cataclysm': 1,
#              'brass': 1,
#              'should': 31,
#              'use': 19,
#              'happy': 11,
#              'variation': 1,
#              'play': 15,
#              'counters': 1,
#              'hard': 7,
#              'style': 3,
#              'jadeformkx': 1,
#              '38nhq9moef': 1,
#              'leads': 3,
#              'carelessness': 1,
#              'aviation': 1,
#              'seek': 4,
#              'right': 37,
#              'damages': 3,
#              'compensation': 2,
#              'eqag6rz1vo': 1,
#              'when': 99,
#              'guys': 7,
#              'sending': 5,
#              'found': 18,
#              'rewind': 1,
#              'cali': 5,
#              'became': 2,
#              'airplane': 14,
#              'fan': 15,
#              'music': 12,
#              'regarding': 2,
#              'support': 10,
#              'today': 44,
#              'lol': 28,
#              'years': 29,
#              'who': 77,
#              'fifteen': 3,
#              'ago': 12,
#              'keio': 1,
#              'know': 43,
#              'btw': 2,
#              'hihow': 1,
#              'line': 19,
#              'mintechan': 1,
#              'stationright': 1,
#              'chofu': 1,
#              'airport': 15,
#              'mx': 1,
#              'government': 12,
#              'coahuila': 1,
#              'ocampo': 1,
#              'francisco': 2,
#              'age': 4,
#              'castells': 1,
#              '25': 7,
#              'killed': 29,
#              'garcia': 1,
#              '42': 4,
#              'mexican': 3,
#              '7': 25,
#              'subsecretariat': 1,
#              '29': 8,
#              'airplaneåê': 1,
#              '07': 3,
#              '5zrkzdhode': 1,
#              'wings': 2,
#              'horrible': 14,
#              'completely': 4,
#              'luggage': 1,
#              'makeup': 2,
#              'destroyed': 25,
#              'idc': 1,
#              'god': 32,
#              'rest': 3,
#              'hg8u2kr1rq': 1,
#              'twp': 1,
#              'picture': 7,
#              '6jfgdnzrlc': 1,
#              'update': 14,
#              'penn': 2,
#              'jfk': 1,
#              'see': 45,
#              'ruled': 4,
#              'judge': 4,
#              'yh1cgln3rl': 1,
#              'air': 18,
#              '6f5shpkjob': 1,
#              'involving': 5,
#              '2009': 1,
#              'korean': 2,
#              'mode': 3,
#              'thugiauren': 1,
#              'rip': 4,
#              'inku28vjjj': 1,
#              'yankees': 2,
#              'baseball': 6,
#              'captain': 1,
#              'lost': 7,
#              '36': 1,
#              'its': 20,
#              'one': 80,
#              'greats': 1,
#              'france': 5,
#              'experts': 4,
#              'french': 5,
#              'begin': 5,
#              'reunion': 8,
#              'miw2i0pqxz': 1,
#              'examining': 3,
#              'debris': 19,
#              'island': 15,
#              'wedn': 2,
#              'e': 12,
#              'breakingnews': 5,
#              '3xicuvlvlj': 1,
#              'kubsm16oud': 1,
#              'helicopter': 8,
#              'feared': 9,
#              'zdsug0ujs7': 1,
#              'twelve': 2,
#              'ambulance': 13,
#              'pakistani': 4,
#              'brightasastar': 1,
#              'q5xtkakm08': 1,
#              'belly': 3,
#              'send': 16,
#              'm': 27,
#              'dying': 2,
#              'automatic': 1,
#              '7x3pddbt0z': 1,
#              'ebay': 12,
#              'choice': 3,
#              'lez': 1,
#              'compliant': 1,
#              'frontline': 1,
#              '14': 5,
#              'sprinter': 1,
#              'well': 16,
#              'laughing': 2,
#              'top': 25,
#              'nearly': 6,
#              'disneyxrowbrina': 1,
#              'parked': 2,
#              "isn't": 12,
#              "someone's": 1,
#              'even': 37,
#              'meudjwaang': 1,
#              'treat': 3,
#              'shot': 7,
#              'involved': 3,
#              'times': 16,
#              'told': 9,
#              'cuffs': 1,
#              'after': 106,
#              '12': 7,
#              'being': 30,
#              'officers': 3,
#              'dead': 39,
#              'rainbowpower': 1,
#              'fag': 1,
#              'margaretcho': 1,
#              'blood': 14,
#              'mnmyjxq9go': 1,
#              'target': 6,
#              'clots': 1,
#              'able': 2,
#              'nanotech': 1,
#              'destroy': 17,
#              'science': 6,
#              'device': 3,
#              'supplies': 2,
#              'vballplaya2296': 1,
#              'medic': 1,
#              "dad's": 1,
#              'some': 49,
#              'd9sowi1g21': 1,
#              'opxmdpiwau': 1,
#              'held': 6,
#              'heroin': 1,
#              'b2fasrt1tn': 1,
#              'o8bjxnepqm': 1,
#              'miles': 4,
#              'transfer': 4,
#              'hospital': 6,
#              '7zqirey7te': 1,
#              'ride': 4,
#              'cost': 4,
#              '21': 4,
#              'why': 59,
#              '9qp3pqpwzv': 1,
#              '29800': 1,
#              'proud': 4,
#              'whatsyouremergency': 1,
#              'gayuk': 1,
#              '0bkmuhysfx': 1,
#              'uniform': 2,
#              'nhs': 1,
#              'privileged': 1,
#              'hsnowberger': 1,
#              'kdunning1919': 1,
#              'bartender': 1,
#              'drunk': 7,
#              'work': 27,
#              'annihilated': 13,
#              'days': 12,
#              'described': 2,
#              'gabrielasmith29': 1,
#              '1kdoztd9mv': 1,
#              'ctl5xzihxaåê': 1,
#              'driver': 5,
#              'viralspell': 4,
#              'seconds': 10,
#              'before': 29,
#              'pulls': 2,
#              'train': 31,
#              'cop': 4,
#              'safety': 11,
#              'cssc8hcsxnåê': 1,
#              'jblgylcsay': 1,
#              'think': 42,
#              'sincerety': 1,
#              'chance': 3,
#              'israel': 18,
#              'un': 3,
#              'fraction': 1,
#              'rosiegray': 1,
#              'move': 11,
#              'now': 81,
#              "'stage'": 1,
#              'stand': 15,
#              'certainly': 2,
#              'never': 36,
#              'drama': 1,
#              'only': 37,
#              'johnboywest': 1,
#              'queen': 3,
#              'stage': 2,
#              'bro': 6,
#              'handplacementgoals': 1,
#              'hashtag': 3,
#              'drodrolagi': 1,
#              '5': 44,
#              'step': 3,
#              'get': 102,
#              'mosquitoes': 1,
#              'outside': 7,
#              'minions': 1,
#              'dreamworks': 1,
#              'first': 56,
#              'strike': 4,
#              'jacksfilms': 1,
#              'yiayplan': 1,
#              'appropriates': 1,
#              'until': 18,
#              'beloved': 2,
#              'nature': 2,
#              "'if": 2,
#              'smlwjund09': 1,
#              'friendship': 2,
#              "annihilated'": 1,
#              'shred': 2,
#              'psych': 1,
#              'ninahoag': 1,
#              'have': 120,
#              'nothing': 11,
#              'y': 3,
#              'v': 5,
#              'while': 21,
#              'wiimington': 1,
#              'prkng': 1,
#              'liberals': 1,
#              'example': 2,
#              'burton': 1,
#              'conservatives': 2,
#              'done': 12,
#              'stood': 3,
#              'thehill': 2,
#              'auth': 5,
#              'aug': 16,
#              'regiment': 1,
#              'carso': 1,
#              'plateau': 1,
#              "joseph's": 1,
#              'crack': 2,
#              'wiped': 1,
#              'francis': 3,
#              '1915\x89ûókaiserjaegers': 1,
#              'd1spswl66h': 1,
#              'they': 74,
#              'die': 11,
#              'everything': 9,
#              'ur7qkqg1wf': 1,
#              'brooo': 1,
#              'dd': 1,
#              'albertbreer': 1,
#              'needed': 4,
#              'stock': 16,
#              'mountain': 2,
#              'red': 27,
#              'gmcr': 1,
#              'hours': 8,
#              'rgreen': 1,
#              'longe': 1,
#              'saltriverwildhorses': 1,
#              'rt': 57,
#              'bx0l87inc8': 1,
#              'gb8ispiarp': 1,
#              'sign': 6,
#              'interesting': 6,
#              'louis': 6,
#              'plans': 9,
#              'german': 2,
#              'ruhxglo18q': 1,
#              'very': 20,
#              'annihilation': 19,
#              'nizer': 1,
#              'allied': 1,
#              'hbupkzwdwq': 1,
#              'horses': 3,
#              'arizona': 2,
#              'petition': 2,
#              'wild': 36,
#              '3tssxphufe': 1,
#              'tonto': 11,
#              'horse': 15,
#              'services': 34,
#              's': 39,
#              'u': 46,
#              'river': 20,
#              'change': 27,
#              'national': 18,
#              'latvr8rzck': 1,
#              'salt': 17,
#              'cmnv6vyfcq': 1,
#              'punished': 1,
#              'souls': 2,
#              'round': 2,
#              'updates': 5,
#              'wjscdvcevh': 1,
#              'latest': 20,
#              'w5rhtuey90': 1,
#              'zhxua8kmae': 1,
#              'bosteenauthfest': 1,
#              'silent': 4,
#              'audio': 3,
#              'print': 3,
#              'planet': 2,
#              '8azjff8esi': 1,
#              'saltriverhorses': 1,
#              'savewildhorses': 1,
#              'urgent': 2,
#              'iced': 1,
#              'jackienatalydlt': 1,
#              'd82wlcp49s': 1,
#              'kaldyctc4h': 1,
#              'every': 14,
#              'sonia': 2,
#              'defeat': 1,
#              'answer': 4,
#              'treated': 2,
#              'incindia': 1,
#              'total': 10,
#              'pakistan': 7,
#              'kttyitow64': 1,
#              'under': 22,
#              'gandhi': 1,
#              'trkg2tpwjm': 1,
#              'k0q4fnbzss': 1,
#              '546uttxzam': 1,
#              'flcqqeznvw': 1,
#              'faxdzi90dy': 1,
#              'n6veojw3s8': 1,
#              'i0z3k0chgg': 1,
#              'signs': 7,
#              'almost': 10,
#              'feels': 5,
#              'si': 1,
#              'spherulitic': 1,
#              'built': 4,
#              'ocurjydrcn': 2,
#              'video': 60,
#              'survive': 24,
#              'minecraft': 7,
#              'youtube': 37,
#              'teamtwiistz': 1,
#              'liked': 19,
#              'futuristic': 2,
#              'jrfjgaac9f': 1,
#              'wither': 3,
#              'night': 31,
#              'bob': 4,
#              '0': 12,
#              'mod': 4,
#              'lucky': 5,
#              'showcase': 3,
#              'thomasa56': 1,
#              'cue': 1,
#              "rr's": 1,
#              'live': 27,
#              'meals': 2,
#              'ever': 22,
#              'any': 32,
#              'script': 2,
#              'comes': 10,
#              'major': 7,
#              'pass': 5,
#              'reasons': 4,
#              'miss': 11,
#              "'apocalypse'": 1,
#              'big': 16,
#              '9': 22,
#              'zombie': 4,
#              'item': 2,
#              "you're": 19,
#              'weapon': 15,
#              'either': 11,
#              'screwed': 2,
#              'askconnor': 2,
#              'franchise': 1,
#              "'event'": 1,
#              'really': 27,
#              'x': 10,
#              'excited': 5,
#              'itskingriffyall': 1,
#              'theme': 1,
#              'men': 12,
#              'dig': 1,
#              'lot': 7,
#              'tmfk': 1,
#              'sounds': 7,
#              'time': 48,
#              "i'll": 19,
#              'artists': 3,
#              'fukushima': 9,
#              'into': 65,
#              'ura': 1,
#              'nuclear': 41,
#              'exclusion': 1,
#              'zone': 12,
#              '3zql0qbluw': 1,
#              'doomsday': 1,
#              'hsleabs1yr': 1,
#              'fiction': 2,
#              'reading': 4,
#              'southern': 7,
#              'prepper': 2,
#              'apocalyptic': 4,
#              'sharecropping': 1,
#              'book': 8,
#              'enthusiastic': 1,
#              'coming': 19,
#              'exited': 2,
#              'hes': 1,
#              'honestly': 2,
#              '5sostag': 1,
#              'could': 33,
#              'n5vimoqhbg': 1,
#              'fat': 4,
#              'proof': 4,
#              'babies': 2,
#              'nephew': 2,
#              'also': 23,
#              '2umsxrzot3': 1,
#              'rescue': 18,
#              'added': 7,
#              'playlist': 6,
#              'd': 6,
#              'meerkat': 1,
#              'princes': 1,
#              'encounters': 1,
#              'oy9es9fvlt': 1,
#              'e89gpnepzt': 1,
#              'students': 4,
#              'omg': 14,
#              'among': 6,
#              'ujriaivqln': 1,
#              'order': 13,
#              'armageddon': 7,
#              '3ty4mgm': 1,
#              'universal': 2,
#              "'armageddon'": 1,
#              'bouajqi3lf': 1,
#              'ep': 2,
#              'stream': 2,
#              'pending': 2,
#              'patent': 2,
#              'culu2owiuc': 1,
#              'london': 5,
#              'superstar': 1,
#              'might': 11,
#              'rise': 13,
#              'hitchbot': 2,
#              'true': 8,
#              'ashes': 8,
#              'invades': 1,
#              'turkey': 16,
#              'xuoh3sjnxf': 1,
#              'halfway': 1,
#              'remaining': 2,
#              'baggage': 1,
#              'bags': 10,
#              'crowd': 2,
#              'remember': 15,
#              'carousel': 1,
#              'earth': 8,
#              'food': 20,
#              'animals': 3,
#              ...})

# %%
token1.document_count
# Out:
# 3263

# %%
y_pre=model.predict(padded_x_test)

# %%
print(y_pre)
# Out:
# [[0.889821  ]
#  [0.5670337 ]
#  [0.9937816 ]
#  ...
#  [0.88692033]
#  [0.99614584]
#  [0.89687806]]

# %%
y_pre = np.around(y_pre)

# %%
y_pre.to_csv('submission.csv')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-88c32c620036> in <module>
# ----> 1 y_pre.to_csv('submission.csv')
#
# AttributeError: 'numpy.ndarray' object has no attribute 'to_csv'

# %%
numpy.savetxt('pre.csv',y_pre, delimiter=',')

# %%
prediction = pd.DataFrame(y_pre, columns=['predictions']).to_csv('prediction.csv')
