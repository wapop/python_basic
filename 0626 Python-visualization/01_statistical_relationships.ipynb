# %% [markdown]
# # 첫번째 예제
# 관계 시각화해보기
# *참고 소스코드
# https://seaborn.pydata.org/tutorial/relational.html

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="darkgrid")

print('test')
# Out:
# test

# %%
tips = sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# 기본: x, y, data 설정
sns.relplot(x="total_bill", y="tip", data=tips);

# %%
# 기본: x, y, data 설정
# hue 설정: 카테고리 분리
sns.relplot(x="total_bill", y="tip", hue="smoker", data=tips);

# %%
# 기본: x, y, data 설정
# hue 설정: 카테고리 분리 (색상 차이)
# style 설정: 카테고리 + 표시형식이 달라짐 (모양)
sns.relplot(x="total_bill", y="tip", hue="smoker", style="smoker",
            data=tips);

# %%
#정리혼자하기
sns.relplot(x="total_bill", y="tip", hue="smoker", style="time", data=tips);

# %%
# hue가 4가지 카테고리라서 색상 다르게 지정해줌-2개는 파랑/주황
sns.relplot(x="total_bill", y="tip", hue="size", data=tips);

# %%
# hue를 size로 두되, 색을 팔레트 색상값으로
sns.relplot(x="total_bill", y="tip", hue="size", palette="ch:r=-.5,l=.75", data=tips);

# %%
# size라는 옵션 등장: 크기를 다르게 표시
# 색이 아니라, 크기로 비교해줘!
sns.relplot(x="total_bill", y="tip", size="size", data=tips);

# %%
#size를 설정할 때, sizes 옵션을 추가설정하면,
#size를 다양하게 설정할 수 있음
sns.relplot(x="total_bill", y="tip", size="size", sizes=(15, 200), data=tips);

# %%
df = pd.DataFrame(dict(time=np.arange(500),
                       value=np.random.randn(500).cumsum()))

# %%
#g.fig.autofmt_xdate()

# %%
#kind=line 
g = sns.relplot(x="time", y="value", kind="line", data=df)
g.fig.autofmt_xdate()

# %%
g = sns.relplot(x="time", y="value", kind="line", data=df)

# %%
g = sns.relplot(x="time", y="value", data=df)

# %%
df = pd.DataFrame(np.random.randn(500, 2).cumsum(axis=0), columns=["x", "y"])
sns.relplot(x="x", y="y", sort=False, kind="line", data=df);

# %%
df = pd.DataFrame(np.random.randn(500, 2).cumsum(axis=0), columns=["x", "y"])
df.head()
# Out:
#           x         y
# 0  0.606768 -1.166134
# 1  0.164329  0.648238
# 2 -0.544010  0.510967
# 3 -0.186284 -0.265214
# 4 -0.425489 -1.520972

# %%
fmri = sns.load_dataset("fmri")

# %%
#선그래프 주변에 오차범위도 함께 표시 (95% 신뢰구간)
sns.relplot(x="timepoint", y="signal", kind="line", data=fmri);

# %%
fmri = sns.load_dataset("fmri")
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
sns.relplot(x="timepoint", y="signal", data=fmri);

# %%
sns.relplot(x="timepoint", y="signal", ci=None, kind="line", data=fmri);

# %%
sns.relplot(x="timepoint", y="signal", ci=sd, kind="line", data=fmri);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-63423ddf25be> in <module>
# ----> 1 sns.relplot(x="timepoint", y="signal", ci=sd, kind="line", data=fmri);
#
# NameError: name 'sd' is not defined

# %%
sns.relplot(x="timepoint", y="signal", estimator=None, kind="line", data=fmri);

# %%
#hue, style 만져서 색맹 혹은 흑백 출력일 때 활용가능,,,

# %%
#여러개의 그래프를 나누고 싶을때는 col="time", row="time" 과 같이.. 여러개 그릴수 있음

# %%
sns.relplot(x="timepoint", y="signal", hue="event", style="event",
            col="subject", col_wrap=5,
            height=3, aspect=.75,
            kind="line", data=fmri.query("region == 'frontal'"));

# %%
#linewidth: 보고서같은거 라인 잘보이게 하려면 세세하게 튜닝가능
#x,y,data만 넣을줄 알면,,,  hue ,style은 자주 쓰이는데 나머지는 여기서 봤었어!하고 찾아쓰기
