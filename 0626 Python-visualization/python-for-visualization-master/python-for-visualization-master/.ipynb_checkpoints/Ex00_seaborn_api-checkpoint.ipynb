# %% [markdown]
# https://seaborn.pydata.org/api.html
#
# ### 1. 변수간 상관관계
#
# #### 1) Relational  plots
#
#     relplot
#     scatterplot
#     lineplot
#
#
#
# #### 2) Regression  plots
#
#     lmplot
#     regplot
#     residplot
#
#
#
# ### 2. 데이터 분포(Distribution plots)
#
#     displot
#     kdeplot
#     rugplot
#
#
#
# ### 3. 범주형 데이터(Categorical plots)
#
#     catplot
#     stripplot
#     swarmplot
#     boxplot
#     violinplot
#     boxenplot
#     pointplot
#     barplot
#     countplot
#
#
#
# ### 4. 매트릭스 형태(Matrix plots)
#
#     heatmap
#     clustermap
#
#
#
# ### 5. 여러 개의 그래프를 한번에 그리기(Multi-plot)
#
#     FacetGird
#     pairplot
#     jointplot

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
# sns.set(style="ticks")

# %%
# import matplotlib as mpl
# 한글폰트 깨지지 않도록
# plt.rc('font', family='NanumGothic')
# print(plt.rcParams['font.family'])
# mpl.rcParams['axes.unicode_minus'] = False

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#lineplot
sns.lineplot(x='total_bill', y='tip', data=tips)

# %%
#scatterplot
#total_bill, tip이랑 어떤 관계가 있을까?

sns.scatterplot(x='total_bill', y='tip', data=tips)

# %%
#total_bill, tip이랑 어떤 관계가 있을까?
# relplot
# scatterplot
# lineplot

# %%
# lmplot
# regplot
# residplot

# %%
# lmplot
sns.lmplot(x='total_bill', y='tip', data=tips)

# %%
#regplot
sns.regplot(x='total_bill', y='tip', data=tips)

# %%
#residplot
sns.residplot(x='total_bill', y='tip', data=tips)

# %%
# total_bill의 분포는?
# displot
# kdeplot
# rugplot

# %%
tips=sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# 요일별 매출(total_bill)
# catplot : kind 지정해서 다양하게 활용가능  kind="bos"하면 박스그래프 그려짐. kind 바꾸면 만능
# stripplot: 점이 위로 솟은 모양
# swarmplot: 솟으면서 꽃잎처럼
# boxplot: 주식할때 많이 보이는
# violinplot: 모양
# boxenplot: 박스인데 위아래 작은네모
# pointplot: 포인트만 이은거... 
# barplot: 막대그래프에 검정선-데이터 분포, 신뢰구간
# countplot: 바플랏의 누적-비슷하게 생김
# distplot: 경향성이라서 값 하나만 받음. ex. sns.distlpot(tips.total_bill)
# kedplot: rugplot 밀도에 대한 내용
# lmplot: 회귀선. scatter먼저 그리고, 이 분포를 가장 잘 설명하는 선을 그려주는것.=regplot 똑같다
# residplot: 0을 기준선으로 data가 얼마나 흩어져 있는지 보고싶을때. 평균선을 눕혔을때
# 사용법은 xydata 만 넣어주거나, data히스토그램.. 넣는 등 해보면 쉬울텐데, 이름보고 스스로 그릴줄알아야
