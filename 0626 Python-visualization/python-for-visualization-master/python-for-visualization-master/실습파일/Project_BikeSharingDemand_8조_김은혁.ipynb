# %% [markdown]
# # Mini Project
#
# ## 자전거 수요량 예측 데이터 분석
# https://www.kaggle.com/c/bike-sharing-demand
#
#
#
# ### 1. 가설 설정
# 데이터 분석 전에 데이터 간의 연관성에 대한 임의의 가설 설정하기
#
# ### 2. 데이터 시각화
# 4종류 이상의 시각화 기법을 사용하여 그래프 그리기
# Seaborn 라이브러리 활용
#
# ### 3. 데이터 분석
# 각 그래프로부터 얻을 수 있는 의미 도출
#
# ### 4. 최초의 가설 검정
# 가설이 유의미한지 여부 판단하기

# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 읽어드릴 파일 경로 : /dataset/bike_sharing_demand_train.csv
filepath = "./dataset/bike_sharing_demand_train.csv"
data = pd.read_csv(filepath)

# %%
data.head()
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %% [markdown]
# # 도표의 너비(14)와 높이(6) 설정
# plt.figure(figsize=(14,6))
#
# # 도표의 제목 설정
# plt.title("Daily Global Streams of Popular Songs in 2017-2018")
#
# # 선그래프 그리기
# sns.lineplot(data=filepath)

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-3daf9f2c163b> in <module>
#       1 plt.figure(figsize=(14,6))
#       2 plt.title("Daily Global Streams of Popular Songs in 2017-2018")
# ----> 3 sns.lineplot(x=filepath['datetime'] ,y=filepath['count'], data=filepath)
#
# TypeError: string indices must be integers

# %%
data.head()
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %%
data['datetime'] = data['datetime'].astype('datetime64')

# %%
data['year'] = data['datetime'].dt.year
data['month'] = data['datetime'].dt.month
data['day'] = data['datetime'].dt.day
data['hour'] = data['datetime'].dt.hour
data['minute'] = data['datetime'].dt.minute
data['second'] = data['datetime'].dt.second

# %%
data.head()
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count  year  month  day  hour  \
# 0        81        0.0       3          13     16  2011      1    1     0
# 1        80        0.0       8          32     40  2011      1    1     1
# 2        80        0.0       5          27     32  2011      1    1     2
# 3        75        0.0       3          10     13  2011      1    1     3
# 4        75        0.0       0           1      1  2011      1    1     4
#
#    minute  second
# 0       0       0
# 1       0       0
# ...

# %%
sns.relplot(x='month' , y='count', data=data)

# %%
sns.relplot(x='season' , y='count', data=data)

# %%
sns.relplot(x='temp' , y='count',hue='season', data=data)

# %%
sns.relplot(x='registered' , y='count',hue='season', data=data)

# %%
sns.relplot(x='registered' , y='count',hue='temp', data=data)

# %%
sns.relplot(x='windspeed', y='count',hue='season' ,data=data)

# %%
sns.catplot(x='season', y='count',hue='workingday' ,data=data)

# %%
def 
a1 = {
    if data['workingday']=1:
    data['count']/5
    else:
    data['count']=data['count']
    
}
sns.catplot(x='month', y='a1',hue='workingday' ,data=data)
# Out:
#   File "<ipython-input-92-6219efa9bb72>", line 2
#     if data['workingday']=1:
#      ^
# SyntaxError: invalid syntax

# %%
plt.figure(figsize=(30,15)) 
sns.catplot(x='temp', y='count',hue='workingday' ,data=data)

# %%
sns.dotplot(x='month' , y='count', data=data)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-88-c155148bc8da> in <module>
# ----> 1 sns.dotplot(x='month' , y='count', data=data64)
#
# AttributeError: module 'seaborn' has no attribute 'dotplot'
