# %% [markdown]
# # Mini Project
#
# ## 자전거 수요량 예측 데이터 분석
# https://www.kaggle.com/c/bike-sharing-demand
#
#
#
# ### 1. 가설 설정
# 데이터 분석 전에 데이터 간의 연관성에 대한 임의의 가설 설정하기
#
# ### 2. 데이터 시각화
# 4종류 이상의 시각화 기법을 사용하여 그래프 그리기
# Seaborn 라이브러리 활용
#
# ### 3. 데이터 분석
# 각 그래프로부터 얻을 수 있는 의미 도출
#
# ### 4. 최초의 가설 검정
# 가설이 유의미한지 여부 판단하기

# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 읽어드릴 파일 경로 : /dataset/bike_sharing_demand_train.csv
filepath = "./dataset/bike_sharing_demand_train.csv"
data = pd.read_csv(filepath)

# %%
data.head()
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    10886 non-null  object
#  1   season      10886 non-null  int64
#  2   holiday     10886 non-null  int64
#  3   workingday  10886 non-null  int64
#  4   weather     10886 non-null  int64
#  5   temp        10886 non-null  float64
#  6   atemp       10886 non-null  float64
#  7   humidity    10886 non-null  int64
#  8   windspeed   10886 non-null  float64
#  9   casual      10886 non-null  int64
#  10  registered  10886 non-null  int64
#  11  count       10886 non-null  int64
# dtypes: float64(3), int64(8), object(1)
# memory usage: 1020.7+ KB

# %%
sns.barplot(x=data['season'],y=data['count'])

# %% [markdown]
# ### season3에 자전거 수요가 가장많다.

# %%
data['datetime']=data['datetime'].astype('datetime64')

# %%
data['year']=data['datetime'].dt.year
data['month']=data['datetime'].dt.month
data['day']=data['datetime'].dt.day
data['hour']=data['datetime'].dt.hour
data['minute']=data['datetime'].dt.minute
data['second']=data['datetime'].dt.second

# %%
data.head()
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count  year  month  day  hour  \
# 0        81        0.0       3          13     16  2011      1    1     0
# 1        80        0.0       8          32     40  2011      1    1     1
# 2        80        0.0       5          27     32  2011      1    1     2
# 3        75        0.0       3          10     13  2011      1    1     3
# 4        75        0.0       0           1      1  2011      1    1     4
#
#    minute  second
# 0       0       0
# 1       0       0
# ...

# %%
sns.lineplot(x='year',y='count',data=data)

# %% [markdown]
# ### 해마다 자전거 수요량이 늘고있다.

# %%
sns.lineplot(x='month',y='count',data=data)

# %%
plt.figure(figsize=(12, 5))
sns.boxplot(data=data, x="month", y="count")

# %% [markdown]
# 일년중 6월에 자전거 수요가 가장 많다.

# %%
sns.lineplot(x='hour',y='count',data=data)

# %%
하루중 8시정도와 18시정도에 자전거 수요가 가장 많다.

# %%
sns.lineplot(x='humidity',y='count',data=data)

# %%
sns.distplot(data['temp'])

# %%
sns.distplot(data['atemp'])

# %%
sns.boxplot(x=data['weather'],y=data['count'])

# %%
sns.stripplot(x='hour',y='count',hue='holiday',data=data)

# %%
data3=data.loc[data['season']==3]
data3
# Out:
#                 datetime  season  holiday  workingday  weather   temp   atemp  \
# 2690 2011-07-01 00:00:00       3        0           1        1  27.06  31.060
# 2691 2011-07-01 01:00:00       3        0           1        1  27.06  31.060
# 2692 2011-07-01 02:00:00       3        0           1        1  25.42  30.305
# 2693 2011-07-01 03:00:00       3        0           1        1  26.24  31.060
# 2694 2011-07-01 04:00:00       3        0           1        1  25.42  31.060
# ...                  ...     ...      ...         ...      ...    ...     ...
# 9514 2012-09-19 19:00:00       3        0           1        1  22.96  26.515
# 9515 2012-09-19 20:00:00       3        0           1        1  21.32  25.000
# 9516 2012-09-19 21:00:00       3        0           1        1  20.50  24.240
# 9517 2012-09-19 22:00:00       3        0           1        1  20.50  24.240
# 9518 2012-09-19 23:00:00       3        0           1        1  19.68  23.485
#
# ...

# %%
data3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2733 entries, 2690 to 9518
# Data columns (total 18 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    2733 non-null   datetime64[ns]
#  1   season      2733 non-null   int64
#  2   holiday     2733 non-null   int64
#  3   workingday  2733 non-null   int64
#  4   weather     2733 non-null   int64
#  5   temp        2733 non-null   float64
#  6   atemp       2733 non-null   float64
#  7   humidity    2733 non-null   int64
#  8   windspeed   2733 non-null   float64
#  9   casual      2733 non-null   int64
#  10  registered  2733 non-null   int64
#  11  count       2733 non-null   int64
#  12  year        2733 non-null   int64
#  13  month       2733 non-null   int64
#  14  day         2733 non-null   int64
#  15  hour        2733 non-null   int64
#  16  minute      2733 non-null   int64
#  17  second      2733 non-null   int64
# ...

# %%
sns.distplot(data3['temp'])

# %%
sns.scatterplot(data=data3, x="temp", y="count", hue="weather")

# %%
sns.boxplot(x=data3['weather'],y=data3['count'])
