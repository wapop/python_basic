# %% [markdown]
# # Mini Project
#
# ## 자전거 수요량 예측 데이터 분석
# https://www.kaggle.com/c/bike-sharing-demand
#
#
#
# ### 1. 가설 설정
# 데이터 분석 전에 데이터 간의 연관성에 대한 임의의 가설 설정하기
#
# ### 2. 데이터 시각화
# 4종류 이상의 시각화 기법을 사용하여 그래프 그리기
# Seaborn 라이브러리 활용
#
# ### 3. 데이터 분석
# 각 그래프로부터 얻을 수 있는 의미 도출
#
# ### 4. 최초의 가설 검정
# 가설이 유의미한지 여부 판단하기

# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 읽어드릴 파일 경로 : /dataset/bike_sharing_demand_train.csv
filepath = "./dataset/bike_sharing_demand_train.csv"
bike_data = pd.read_csv(filepath)

# %%
sns.lineplot(x='year', y='count', data=bike_data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-97-92129d435049> in <module>
# ----> 1 sns.lineplot(x='year', y='count', data=bike_data)
#
# ~\anaconda3\lib\site-packages\seaborn\relational.py in lineplot(x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, seed, sort, err_style, err_kws, legend, ax, **kwargs)
#    1129         dashes=dashes, markers=markers, style_order=style_order,
#    1130         units=units, estimator=estimator, ci=ci, n_boot=n_boot, seed=seed,
# -> 1131         sort=sort, err_style=err_style, err_kws=err_kws, legend=legend,
#    1132     )
#    1133
#
# ...

# %%
data.head(20)
# Out:
#               datetime  season  holiday  workingday  weather   temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1   9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1   9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1   9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1   9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1   9.84  14.395
# 5  2011-01-01 05:00:00       1        0           0        2   9.84  12.880
# 6  2011-01-01 06:00:00       1        0           0        1   9.02  13.635
# 7  2011-01-01 07:00:00       1        0           0        1   8.20  12.880
# 8  2011-01-01 08:00:00       1        0           0        1   9.84  14.395
# 9  2011-01-01 09:00:00       1        0           0        1  13.12  17.425
# 10 2011-01-01 10:00:00       1        0           0        1  15.58  19.695
# ...

# %%
data.dtypes
# Out:
# datetime      datetime64[ns]
# season                 int64
# holiday                int64
# workingday             int64
# weather                int64
# temp                 float64
# atemp                float64
# humidity               int64
# windspeed            float64
# casual                 int64
# registered             int64
# count                  int64
# year                   int64
# month                  int64
# day                    int64
# hour                   int64
# minute                 int64
# second                 int64
# dtype: object

# %%
data['year'] = data['datetime'].dt.year
data['month'] = data['datetime'].dt.month
data['day'] = data['datetime'].dt.day
data['hour'] = data['datetime'].dt.hour
data['minute'] = data['datetime'].dt.minute
data['second'] = data['datetime'].dt.second

# %%
# data['datetime'] = pd.to_datetime(data['datetime'], errors='coerce')

# %%
data.head()
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count  year  month  day  hour  \
# 0        81        0.0       3          13     16  2011      1    1     0
# 1        80        0.0       8          32     40  2011      1    1     1
# 2        80        0.0       5          27     32  2011      1    1     2
# 3        75        0.0       3          10     13  2011      1    1     3
# 4        75        0.0       0           1      1  2011      1    1     4
#
#    minute  second
# 0       0       0
# 1       0       0
# ...

# %%
sns.lineplot(x='year', y='count', data=bike_data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-98-92129d435049> in <module>
# ----> 1 sns.lineplot(x='year', y='count', data=bike_data)
#
# ~\anaconda3\lib\site-packages\seaborn\relational.py in lineplot(x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, seed, sort, err_style, err_kws, legend, ax, **kwargs)
#    1129         dashes=dashes, markers=markers, style_order=style_order,
#    1130         units=units, estimator=estimator, ci=ci, n_boot=n_boot, seed=seed,
# -> 1131         sort=sort, err_style=err_style, err_kws=err_kws, legend=legend,
#    1132     )
#    1133
#
# ...

# %% [markdown]
# #### 습기가 높으면 자전거 판매량이 줄어들 것이다.

# %%
#습기에 따른 자전거 판매 수

plt.figure(figsize=(20, 10))
sns.barplot(data=bike_data, x="humidity", y="count")

plt.ylim(0, None)
plt.xlim(0, 90)
# Out:
# (0, 90)

# %% [markdown]
# #### 봄과 가을에 판매량이 제일 많을 것이다.

# %%
# boxplot (season별)


sns.set(style="ticks", palette="pastel")

# Draw a nested boxplot to show bills by day and time
plt.figure(figsize=(10, 5))
sns.boxplot(x="season", y="count",
            palette=["m", "g"],
            data=bike_data)
sns.despine(offset=10, trim=True)

# %% [markdown]
# ### 날씨가 좋을수록 자전거 판매량 높을 것이다.

# %%
# boxplot (weather별,  - category)


sns.set(style="ticks", palette="pastel")

# Draw a nested boxplot to show bills by day and time`

plt.figure(figsize=(10, 10))
sns.boxplot(x="weather", y="count",
            palette=["m", "g"],
            data=bike_data)
sns.despine(offset=20, trim=True)
