# %% [markdown]
# # Mini Project
#
# ## 자전거 수요량 예측 데이터 분석
# https://www.kaggle.com/c/bike-sharing-demand
#
#
#
# ### 1. 가설 설정
# 데이터 분석 전에 데이터 간의 연관성에 대한 임의의 가설 설정하기
#
# ### 2. 데이터 시각화
# 4종류 이상의 시각화 기법을 사용하여 그래프 그리기
# Seaborn 라이브러리 활용
#
# ### 3. 데이터 분석
# 각 그래프로부터 얻을 수 있는 의미 도출
#
# ### 4. 최초의 가설 검정
# 가설이 유의미한지 여부 판단하기

# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 읽어드릴 파일 경로 : /dataset/bike_sharing_demand_train.csv
filepath = "./bike_sharing_demand_train.csv"
data = pd.read_csv(filepath)

# %%
data.head()
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %% [markdown]
# # datetime 정리

# %%
# 데이터타입 확인
data.dtypes
# Out:
# datetime       object
# season          int64
# holiday         int64
# workingday      int64
# weather         int64
# temp          float64
# atemp         float64
# humidity        int64
# windspeed     float64
# casual          int64
# registered      int64
# count           int64
# dtype: object

# %%
# 데이터타입 변경
data['datetime']=data['datetime'].astype('datetime64')
data.dtypes
# Out:
# datetime      datetime64[ns]
# season                 int64
# holiday                int64
# workingday             int64
# weather                int64
# temp                 float64
# atemp                float64
# humidity               int64
# windspeed            float64
# casual                 int64
# registered             int64
# count                  int64
# dtype: object

# %%
data['year']=data['datetime'].dt.year
data['month']=data['datetime'].dt.month
data['day']=data['datetime'].dt.day
data['hour']=data['datetime'].dt.hour
data['minute']=data['datetime'].dt.minute
data['second']=data['datetime'].dt.second

# %% [markdown]
# # 계절

# %%
sns.barplot(x='season', y='count',data=data)

# %% [markdown]
# ##### 가을>여름>겨울>봄

# %% [markdown]
# # 휴일 유무

# %%
sns.countplot(x='holiday',data=data)

# %% [markdown]
# ##### 휴일인 날이 너무 적어서 의미가 적음 나중에 hue값으로 확인 ㄱㄱ

# %% [markdown]
# # 워킹데이

# %%
sns.barplot(x='workingday', y='count',data=data)

# %% [markdown]
# ##### 의미없는 변수

# %% [markdown]
# sns.countplot(x='workingday',data=data)

# %% [markdown]
# # 날씨

# %%
sns.barplot(x='weather', y='count',data=data)

# %% [markdown]
# ##### 맑은날>흐린날>매우안좋은날>살짝 안좋은날

# %% [markdown]
# # 기온

# %%
f, (ax1, ax2) = plt.subplots(2, 1, figsize=(7, 5), sharex=True)

sns.scatterplot(x='temp', y='count', data=data, ax=ax1)
sns.scatterplot(x='atemp', y='count', data=data, ax=ax2)

# %% [markdown]
# ##### 위에가 실재 기온, 아래가 체감: 자전거 타는 양태는 비슷한 양상을 보임(사람들이 실재 기온보다 더 덥게 느끼는 경향이 있지만 실재 타는 양엔 영향 ㄴㄴ)

# %% [markdown]
# # 습도

# %%
sns.scatterplot(x='humidity',y='count',data=data)

# %% [markdown]
# ##### 딱히 습도에 영향 ㄴㄴ

# %% [markdown]
# # 바람속도

# %%
sns.distplot(x='windspeed', y='count',data=data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-55-a0b5a44f1134> in <module>
# ----> 1 sns.distplot(x='windspeed', y='count',data=data)
#
# TypeError: distplot() got an unexpected keyword argument 'x'

# %% [markdown]
# # 비회원제 & 회원제

# %%
# data.casual=0
# length=len(data)

Casual=data['casual']
print(Casual)


# for i in range(length):
#     data.casual+=dataㅣㅐ
# data.casual
# Out:
# 0         3
# 1         8
# 2         5
# 3         3
# 4         0
#          ..
# 10881     7
# 10882    10
# 10883     4
# 10884    12
# 10885     4
# Name: casual, Length: 10886, dtype: int64

# %%
sns.barplot(x='data.casual', y='',data=data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-85-906ddf4a733e> in <module>
# ----> 1 sns.barplot(x='data.casual', y='',data=data)
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3148                           estimator, ci, n_boot, units, seed,
#    3149                           orient, color, palette, saturation,
# -> 3150                           errcolor, errwidth, capsize, dodge)
#    3151
#    3152     if ax is None:
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
# ...

# %% [markdown]
# # 회원제

# %%
sns.barplot(x='registered', y='count',data=data)
