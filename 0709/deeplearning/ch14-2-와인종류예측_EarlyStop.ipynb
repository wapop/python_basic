# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import ModelCheckpoint,EarlyStopping

import pandas as pd
import numpy
import os
import tensorflow as tf

# seed 값 설정
numpy.random.seed(3)
tf.random.set_seed(3)

# %% [markdown]
# ## 1. 데이터 읽어오기

# %%
df_pre = pd.read_csv('./dataset/wine.csv', header=None)
df = df_pre.sample(frac=0.15)
df.info()
# df_pre.info() 
# frac: 15프로만 가지고 샘플링
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 975 entries, 3553 to 844
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       975 non-null    float64
#  1   1       975 non-null    float64
#  2   2       975 non-null    float64
#  3   3       975 non-null    float64
#  4   4       975 non-null    float64
#  5   5       975 non-null    float64
#  6   6       975 non-null    float64
#  7   7       975 non-null    float64
#  8   8       975 non-null    float64
#  9   9       975 non-null    float64
#  10  10      975 non-null    float64
#  11  11      975 non-null    int64
#  12  12      975 non-null    int64
# dtypes: float64(11), int64(2)
# memory usage: 106.6 KB

# %% [markdown]
# ## 2. 데이터 전처리

# %%
dataset = df.values
X = dataset[:,0:12]
Y = dataset[:,12]

# %% [markdown]
# ## 3. 모델 설계

# %%
model = Sequential()
model.add(Dense(30,  input_dim=12, activation='relu'))
model.add(Dense(12, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %% [markdown]
# ## 4. 모델 컴파일

# %%
model.compile(loss='binary_crossentropy',
          optimizer='adam',
          metrics=['accuracy'])

# %% [markdown]
# ## 5. 학습

# %%
# 모델 저장 폴더 만들기
MODEL_DIR = './model/'
if not os.path.exists(MODEL_DIR):
   os.mkdir(MODEL_DIR)

modelpath="./model/{epoch:02d}-{val_loss:.4f}.hdf5"

# 모델 업데이트 및 저장
checkpointer = ModelCheckpoint(filepath=modelpath, monitor='val_loss', verbose=1, save_best_only=True)

# 학습 자동 중단 설정
early_stopping_callback = EarlyStopping(monitor='val_loss', patience=100)

model.fit(X, Y, validation_split=0.2, epochs=3500, batch_size=500, verbose=0, callbacks=[early_stopping_callback,checkpointer])


# 콜백: 이벤트를 시스템에 미리 걸어놓고 이벤트가 발생하면 그 때 나를 깨워줘. : 핸드폰에서 터치이벤트에 대해 화면 켜는 기능 실행
# 함수는 함수명써서 내가 호출하는데, 
# 체크포인트: val_loss 값을 모니터링하고 early_stopping_callback를 깨우는데, 100번 참은 후에 깨어나서 fit을 멈추게할거라는,,
# Out:
# Epoch 00001: val_loss improved from inf to 1.36072, saving model to ./model/01-1.3607.hdf5
#
# Epoch 00002: val_loss improved from 1.36072 to 0.95262, saving model to ./model/02-0.9526.hdf5
#
# Epoch 00003: val_loss improved from 0.95262 to 0.62346, saving model to ./model/03-0.6235.hdf5
#
# Epoch 00004: val_loss did not improve from 0.62346
#
# Epoch 00005: val_loss did not improve from 0.62346
#
# Epoch 00006: val_loss improved from 0.62346 to 0.50412, saving model to ./model/06-0.5041.hdf5
#
# Epoch 00007: val_loss improved from 0.50412 to 0.48386, saving model to ./model/07-0.4839.hdf5
#
# Epoch 00008: val_loss did not improve from 0.48386
#
# Epoch 00009: val_loss did not improve from 0.48386
#
# Epoch 00010: val_loss improved from 0.48386 to 0.46836, saving model to ./model/10-0.4684.hdf5
#
# Epoch 00011: val_loss improved from 0.46836 to 0.42798, saving model to ./model/11-0.4280.hdf5
#
# Epoch 00012: val_loss improved from 0.42798 to 0.39563, saving model to ./model/12-0.3956.hdf5
#
# Epoch 00013: val_loss improved from 0.39563 to 0.39267, saving model to ./model/13-0.3927.hdf5
#
# Epoch 00014: val_loss did not improve from 0.39267
#
# Epoch 00015: val_loss improved from 0.39267 to 0.38901, saving model to ./model/15-0.3890.hdf5
#
# Epoch 00016: val_loss improved from 0.38901 to 0.36011, saving model to ./model/16-0.3601.hdf5
#
# Epoch 00017: val_loss improved from 0.36011 to 0.34598, saving model to ./model/17-0.3460.hdf5
#
# Epoch 00018: val_loss improved from 0.34598 to 0.34150, saving model to ./model/18-0.3415.hdf5
#
# Epoch 00019: val_loss improved from 0.34150 to 0.33688, saving model to ./model/19-0.3369.hdf5
#
# Epoch 00020: val_loss improved from 0.33688 to 0.32920, saving model to ./model/20-0.3292.hdf5
#
# Epoch 00021: val_loss improved from 0.32920 to 0.32054, saving model to ./model/21-0.3205.hdf5
#
# Epoch 00022: val_loss improved from 0.32054 to 0.31551, saving model to ./model/22-0.3155.hdf5
#
# Epoch 00023: val_loss improved from 0.31551 to 0.31450, saving model to ./model/23-0.3145.hdf5
#
# Epoch 00024: val_loss improved from 0.31450 to 0.31287, saving model to ./model/24-0.3129.hdf5
#
# Epoch 00025: val_loss improved from 0.31287 to 0.30783, saving model to ./model/25-0.3078.hdf5
#
# Epoch 00026: val_loss improved from 0.30783 to 0.30236, saving model to ./model/26-0.3024.hdf5
#
# Epoch 00027: val_loss improved from 0.30236 to 0.29849, saving model to ./model/27-0.2985.hdf5
#
# Epoch 00028: val_loss improved from 0.29849 to 0.29579, saving model to ./model/28-0.2958.hdf5
#
# Epoch 00029: val_loss improved from 0.29579 to 0.29326, saving model to ./model/29-0.2933.hdf5
#
# Epoch 00030: val_loss improved from 0.29326 to 0.29040, saving model to ./model/30-0.2904.hdf5
#
# Epoch 00031: val_loss improved from 0.29040 to 0.28769, saving model to ./model/31-0.2877.hdf5
#
# Epoch 00032: val_loss improved from 0.28769 to 0.28537, saving model to ./model/32-0.2854.hdf5
#
# Epoch 00033: val_loss improved from 0.28537 to 0.28345, saving model to ./model/33-0.2834.hdf5
#
# Epoch 00034: val_loss improved from 0.28345 to 0.28154, saving model to ./model/34-0.2815.hdf5
#
# Epoch 00035: val_loss improved from 0.28154 to 0.28027, saving model to ./model/35-0.2803.hdf5
#
# Epoch 00036: val_loss improved from 0.28027 to 0.28004, saving model to ./model/36-0.2800.hdf5
#
# Epoch 00037: val_loss did not improve from 0.28004
#
# Epoch 00038: val_loss did not improve from 0.28004
#
# Epoch 00039: val_loss did not improve from 0.28004
#
# Epoch 00040: val_loss improved from 0.28004 to 0.27854, saving model to ./model/40-0.2785.hdf5
#
# Epoch 00041: val_loss improved from 0.27854 to 0.27467, saving model to ./model/41-0.2747.hdf5
#
# Epoch 00042: val_loss improved from 0.27467 to 0.27084, saving model to ./model/42-0.2708.hdf5
#
# Epoch 00043: val_loss improved from 0.27084 to 0.26760, saving model to ./model/43-0.2676.hdf5
#
# Epoch 00044: val_loss improved from 0.26760 to 0.26462, saving model to ./model/44-0.2646.hdf5
#
# Epoch 00045: val_loss improved from 0.26462 to 0.26203, saving model to ./model/45-0.2620.hdf5
#
# Epoch 00046: val_loss improved from 0.26203 to 0.25992, saving model to ./model/46-0.2599.hdf5
#
# Epoch 00047: val_loss improved from 0.25992 to 0.25821, saving model to ./model/47-0.2582.hdf5
#
# Epoch 00048: val_loss improved from 0.25821 to 0.25695, saving model to ./model/48-0.2570.hdf5
#
# Epoch 00049: val_loss improved from 0.25695 to 0.25608, saving model to ./model/49-0.2561.hdf5
#
# Epoch 00050: val_loss improved from 0.25608 to 0.25517, saving model to ./model/50-0.2552.hdf5
#
# Epoch 00051: val_loss improved from 0.25517 to 0.25457, saving model to ./model/51-0.2546.hdf5
#
# Epoch 00052: val_loss improved from 0.25457 to 0.25317, saving model to ./model/52-0.2532.hdf5
#
# Epoch 00053: val_loss improved from 0.25317 to 0.25221, saving model to ./model/53-0.2522.hdf5
#
# Epoch 00054: val_loss improved from 0.25221 to 0.25161, saving model to ./model/54-0.2516.hdf5
#
# Epoch 00055: val_loss improved from 0.25161 to 0.25107, saving model to ./model/55-0.2511.hdf5
#
# Epoch 00056: val_loss improved from 0.25107 to 0.25078, saving model to ./model/56-0.2508.hdf5
#
# Epoch 00057: val_loss did not improve from 0.25078
#
# Epoch 00058: val_loss did not improve from 0.25078
#
# Epoch 00059: val_loss did not improve from 0.25078
#
# Epoch 00060: val_loss did not improve from 0.25078
#
# Epoch 00061: val_loss did not improve from 0.25078
#
# Epoch 00062: val_loss did not improve from 0.25078
#
# Epoch 00063: val_loss did not improve from 0.25078
#
# Epoch 00064: val_loss did not improve from 0.25078
#
# Epoch 00065: val_loss did not improve from 0.25078
#
# Epoch 00066: val_loss improved from 0.25078 to 0.25057, saving model to ./model/66-0.2506.hdf5
#
# Epoch 00067: val_loss improved from 0.25057 to 0.24978, saving model to ./model/67-0.2498.hdf5
#
# Epoch 00068: val_loss improved from 0.24978 to 0.24832, saving model to ./model/68-0.2483.hdf5
#
# Epoch 00069: val_loss improved from 0.24832 to 0.24735, saving model to ./model/69-0.2474.hdf5
#
# Epoch 00070: val_loss improved from 0.24735 to 0.24663, saving model to ./model/70-0.2466.hdf5
#
# Epoch 00071: val_loss improved from 0.24663 to 0.24588, saving model to ./model/71-0.2459.hdf5
#
# Epoch 00072: val_loss improved from 0.24588 to 0.24527, saving model to ./model/72-0.2453.hdf5
#
# Epoch 00073: val_loss improved from 0.24527 to 0.24498, saving model to ./model/73-0.2450.hdf5
#
# Epoch 00074: val_loss improved from 0.24498 to 0.24483, saving model to ./model/74-0.2448.hdf5
#
# Epoch 00075: val_loss did not improve from 0.24483
#
# Epoch 00076: val_loss did not improve from 0.24483
#
# Epoch 00077: val_loss did not improve from 0.24483
#
# Epoch 00078: val_loss did not improve from 0.24483
#
# Epoch 00079: val_loss did not improve from 0.24483
#
# Epoch 00080: val_loss did not improve from 0.24483
#
# Epoch 00081: val_loss did not improve from 0.24483
#
# Epoch 00082: val_loss improved from 0.24483 to 0.24417, saving model to ./model/82-0.2442.hdf5
#
# Epoch 00083: val_loss improved from 0.24417 to 0.24373, saving model to ./model/83-0.2437.hdf5
#
# Epoch 00084: val_loss improved from 0.24373 to 0.24338, saving model to ./model/84-0.2434.hdf5
#
# Epoch 00085: val_loss improved from 0.24338 to 0.24310, saving model to ./model/85-0.2431.hdf5
#
# Epoch 00086: val_loss improved from 0.24310 to 0.24263, saving model to ./model/86-0.2426.hdf5
#
# Epoch 00087: val_loss improved from 0.24263 to 0.24193, saving model to ./model/87-0.2419.hdf5
#
# Epoch 00088: val_loss improved from 0.24193 to 0.24147, saving model to ./model/88-0.2415.hdf5
#
# Epoch 00089: val_loss improved from 0.24147 to 0.24088, saving model to ./model/89-0.2409.hdf5
#
# Epoch 00090: val_loss improved from 0.24088 to 0.24018, saving model to ./model/90-0.2402.hdf5
#
# Epoch 00091: val_loss improved from 0.24018 to 0.23949, saving model to ./model/91-0.2395.hdf5
#
# Epoch 00092: val_loss improved from 0.23949 to 0.23907, saving model to ./model/92-0.2391.hdf5
#
# Epoch 00093: val_loss improved from 0.23907 to 0.23887, saving model to ./model/93-0.2389.hdf5
#
# Epoch 00094: val_loss improved from 0.23887 to 0.23860, saving model to ./model/94-0.2386.hdf5
#
# Epoch 00095: val_loss did not improve from 0.23860
#
# Epoch 00096: val_loss did not improve from 0.23860
#
# Epoch 00097: val_loss improved from 0.23860 to 0.23852, saving model to ./model/97-0.2385.hdf5
#
# Epoch 00098: val_loss did not improve from 0.23852
#
# Epoch 00099: val_loss did not improve from 0.23852
#
# Epoch 00100: val_loss improved from 0.23852 to 0.23815, saving model to ./model/100-0.2382.hdf5
#
# Epoch 00101: val_loss improved from 0.23815 to 0.23754, saving model to ./model/101-0.2375.hdf5
# Epoch 00102: val_loss improved from 0.23754 to 0.23685, saving model to ./model/102-0.2368.hdf5
#
# Epoch 00103: val_loss improved from 0.23685 to 0.23621, saving model to ./model/103-0.2362.hdf5
#
# Epoch 00104: val_loss improved from 0.23621 to 0.23499, saving model to ./model/104-0.2350.hdf5
#
# Epoch 00105: val_loss improved from 0.23499 to 0.23402, saving model to ./model/105-0.2340.hdf5
#
# Epoch 00106: val_loss improved from 0.23402 to 0.23355, saving model to ./model/106-0.2335.hdf5
#
# Epoch 00107: val_loss improved from 0.23355 to 0.23325, saving model to ./model/107-0.2332.hdf5
#
# Epoch 00108: val_loss did not improve from 0.23325
#
# Epoch 00109: val_loss did not improve from 0.23325
#
# Epoch 00110: val_loss did not improve from 0.23325
#
# Epoch 00111: val_loss did not improve from 0.23325
#
# Epoch 00112: val_loss did not improve from 0.23325
#
# Epoch 00113: val_loss did not improve from 0.23325
#
# Epoch 00114: val_loss improved from 0.23325 to 0.23275, saving model to ./model/114-0.2328.hdf5
#
# Epoch 00115: val_loss improved from 0.23275 to 0.23258, saving model to ./model/115-0.2326.hdf5
#
# Epoch 00116: val_loss improved from 0.23258 to 0.23257, saving model to ./model/116-0.2326.hdf5
#
# Epoch 00117: val_loss improved from 0.23257 to 0.23254, saving model to ./model/117-0.2325.hdf5
#
# Epoch 00118: val_loss did not improve from 0.23254
#
# Epoch 00119: val_loss did not improve from 0.23254
#
# Epoch 00120: val_loss did not improve from 0.23254
#
# Epoch 00121: val_loss did not improve from 0.23254
#
# Epoch 00122: val_loss improved from 0.23254 to 0.23214, saving model to ./model/122-0.2321.hdf5
#
# Epoch 00123: val_loss improved from 0.23214 to 0.23094, saving model to ./model/123-0.2309.hdf5
#
# Epoch 00124: val_loss improved from 0.23094 to 0.22982, saving model to ./model/124-0.2298.hdf5
#
# Epoch 00125: val_loss improved from 0.22982 to 0.22896, saving model to ./model/125-0.2290.hdf5
#
# Epoch 00126: val_loss improved from 0.22896 to 0.22872, saving model to ./model/126-0.2287.hdf5
#
# Epoch 00127: val_loss improved from 0.22872 to 0.22796, saving model to ./model/127-0.2280.hdf5
#
# Epoch 00128: val_loss improved from 0.22796 to 0.22711, saving model to ./model/128-0.2271.hdf5
#
# Epoch 00129: val_loss improved from 0.22711 to 0.22666, saving model to ./model/129-0.2267.hdf5
#
# Epoch 00130: val_loss did not improve from 0.22666
#
# Epoch 00131: val_loss improved from 0.22666 to 0.22654, saving model to ./model/131-0.2265.hdf5
#
# Epoch 00132: val_loss improved from 0.22654 to 0.22649, saving model to ./model/132-0.2265.hdf5
#
# Epoch 00133: val_loss improved from 0.22649 to 0.22631, saving model to ./model/133-0.2263.hdf5
#
# Epoch 00134: val_loss improved from 0.22631 to 0.22591, saving model to ./model/134-0.2259.hdf5
#
# Epoch 00135: val_loss improved from 0.22591 to 0.22524, saving model to ./model/135-0.2252.hdf5
#
# Epoch 00136: val_loss improved from 0.22524 to 0.22460, saving model to ./model/136-0.2246.hdf5
#
# Epoch 00137: val_loss improved from 0.22460 to 0.22403, saving model to ./model/137-0.2240.hdf5
#
# Epoch 00138: val_loss improved from 0.22403 to 0.22358, saving model to ./model/138-0.2236.hdf5
#
# Epoch 00139: val_loss improved from 0.22358 to 0.22346, saving model to ./model/139-0.2235.hdf5
#
# Epoch 00140: val_loss improved from 0.22346 to 0.22316, saving model to ./model/140-0.2232.hdf5
#
# Epoch 00141: val_loss improved from 0.22316 to 0.22300, saving model to ./model/141-0.2230.hdf5
#
# Epoch 00142: val_loss improved from 0.22300 to 0.22264, saving model to ./model/142-0.2226.hdf5
#
# Epoch 00143: val_loss improved from 0.22264 to 0.22238, saving model to ./model/143-0.2224.hdf5
#
# Epoch 00144: val_loss improved from 0.22238 to 0.22198, saving model to ./model/144-0.2220.hdf5
#
# Epoch 00145: val_loss improved from 0.22198 to 0.22158, saving model to ./model/145-0.2216.hdf5
#
# Epoch 00146: val_loss improved from 0.22158 to 0.22099, saving model to ./model/146-0.2210.hdf5
#
# Epoch 00147: val_loss improved from 0.22099 to 0.22034, saving model to ./model/147-0.2203.hdf5
#
# Epoch 00148: val_loss improved from 0.22034 to 0.22005, saving model to ./model/148-0.2200.hdf5
#
# Epoch 00149: val_loss improved from 0.22005 to 0.21934, saving model to ./model/149-0.2193.hdf5
#
# Epoch 00150: val_loss improved from 0.21934 to 0.21921, saving model to ./model/150-0.2192.hdf5
#
# Epoch 00151: val_loss did not improve from 0.21921
#
# Epoch 00152: val_loss improved from 0.21921 to 0.21892, saving model to ./model/152-0.2189.hdf5
#
# Epoch 00153: val_loss did not improve from 0.21892
#
# Epoch 00154: val_loss did not improve from 0.21892
#
# Epoch 00155: val_loss did not improve from 0.21892
#
# Epoch 00156: val_loss improved from 0.21892 to 0.21813, saving model to ./model/156-0.2181.hdf5
#
# Epoch 00157: val_loss improved from 0.21813 to 0.21734, saving model to ./model/157-0.2173.hdf5
#
# Epoch 00158: val_loss improved from 0.21734 to 0.21687, saving model to ./model/158-0.2169.hdf5
#
# Epoch 00159: val_loss improved from 0.21687 to 0.21647, saving model to ./model/159-0.2165.hdf5
#
# Epoch 00160: val_loss improved from 0.21647 to 0.21582, saving model to ./model/160-0.2158.hdf5
#
# Epoch 00161: val_loss improved from 0.21582 to 0.21505, saving model to ./model/161-0.2150.hdf5
#
# Epoch 00162: val_loss improved from 0.21505 to 0.21446, saving model to ./model/162-0.2145.hdf5
#
# Epoch 00163: val_loss did not improve from 0.21446
#
# Epoch 00164: val_loss did not improve from 0.21446
#
# Epoch 00165: val_loss did not improve from 0.21446
#
# Epoch 00166: val_loss did not improve from 0.21446
#
# Epoch 00167: val_loss improved from 0.21446 to 0.21423, saving model to ./model/167-0.2142.hdf5
#
# Epoch 00168: val_loss improved from 0.21423 to 0.21325, saving model to ./model/168-0.2132.hdf5
#
# Epoch 00169: val_loss improved from 0.21325 to 0.21231, saving model to ./model/169-0.2123.hdf5
#
# Epoch 00170: val_loss improved from 0.21231 to 0.21201, saving model to ./model/170-0.2120.hdf5
#
# Epoch 00171: val_loss improved from 0.21201 to 0.21171, saving model to ./model/171-0.2117.hdf5
#
# Epoch 00172: val_loss improved from 0.21171 to 0.21156, saving model to ./model/172-0.2116.hdf5
#
# Epoch 00173: val_loss did not improve from 0.21156
#
# Epoch 00174: val_loss improved from 0.21156 to 0.21145, saving model to ./model/174-0.2115.hdf5
#
# Epoch 00175: val_loss improved from 0.21145 to 0.21096, saving model to ./model/175-0.2110.hdf5
#
# Epoch 00176: val_loss improved from 0.21096 to 0.21024, saving model to ./model/176-0.2102.hdf5
#
# Epoch 00177: val_loss improved from 0.21024 to 0.20943, saving model to ./model/177-0.2094.hdf5
#
# Epoch 00178: val_loss improved from 0.20943 to 0.20902, saving model to ./model/178-0.2090.hdf5
#
# Epoch 00179: val_loss improved from 0.20902 to 0.20878, saving model to ./model/179-0.2088.hdf5
#
# Epoch 00180: val_loss improved from 0.20878 to 0.20814, saving model to ./model/180-0.2081.hdf5
#
# Epoch 00181: val_loss improved from 0.20814 to 0.20780, saving model to ./model/181-0.2078.hdf5
#
# Epoch 00182: val_loss improved from 0.20780 to 0.20744, saving model to ./model/182-0.2074.hdf5
#
# Epoch 00183: val_loss improved from 0.20744 to 0.20714, saving model to ./model/183-0.2071.hdf5
#
# Epoch 00184: val_loss improved from 0.20714 to 0.20669, saving model to ./model/184-0.2067.hdf5
#
# Epoch 00185: val_loss improved from 0.20669 to 0.20643, saving model to ./model/185-0.2064.hdf5
#
# Epoch 00186: val_loss improved from 0.20643 to 0.20609, saving model to ./model/186-0.2061.hdf5
#
# Epoch 00187: val_loss improved from 0.20609 to 0.20571, saving model to ./model/187-0.2057.hdf5
#
# Epoch 00188: val_loss improved from 0.20571 to 0.20544, saving model to ./model/188-0.2054.hdf5
#
# Epoch 00189: val_loss improved from 0.20544 to 0.20500, saving model to ./model/189-0.2050.hdf5
#
# Epoch 00190: val_loss improved from 0.20500 to 0.20417, saving model to ./model/190-0.2042.hdf5
#
# Epoch 00191: val_loss improved from 0.20417 to 0.20368, saving model to ./model/191-0.2037.hdf5
#
# Epoch 00192: val_loss improved from 0.20368 to 0.20328, saving model to ./model/192-0.2033.hdf5
#
# Epoch 00193: val_loss improved from 0.20328 to 0.20283, saving model to ./model/193-0.2028.hdf5
#
# Epoch 00194: val_loss improved from 0.20283 to 0.20200, saving model to ./model/194-0.2020.hdf5
#
# Epoch 00195: val_loss improved from 0.20200 to 0.20174, saving model to ./model/195-0.2017.hdf5
#
# Epoch 00196: val_loss did not improve from 0.20174
#
# Epoch 00197: val_loss improved from 0.20174 to 0.20171, saving model to ./model/197-0.2017.hdf5
#
# Epoch 00198: val_loss improved from 0.20171 to 0.20163, saving model to ./model/198-0.2016.hdf5
# Epoch 00199: val_loss improved from 0.20163 to 0.20154, saving model to ./model/199-0.2015.hdf5
#
# Epoch 00200: val_loss did not improve from 0.20154
#
# Epoch 00201: val_loss improved from 0.20154 to 0.20151, saving model to ./model/201-0.2015.hdf5
#
# Epoch 00202: val_loss improved from 0.20151 to 0.20024, saving model to ./model/202-0.2002.hdf5
#
# Epoch 00203: val_loss improved from 0.20024 to 0.20007, saving model to ./model/203-0.2001.hdf5
#
# Epoch 00204: val_loss improved from 0.20007 to 0.19939, saving model to ./model/204-0.1994.hdf5
#
# Epoch 00205: val_loss improved from 0.19939 to 0.19852, saving model to ./model/205-0.1985.hdf5
#
# Epoch 00206: val_loss improved from 0.19852 to 0.19773, saving model to ./model/206-0.1977.hdf5
#
# Epoch 00207: val_loss improved from 0.19773 to 0.19732, saving model to ./model/207-0.1973.hdf5
#
# Epoch 00208: val_loss improved from 0.19732 to 0.19675, saving model to ./model/208-0.1968.hdf5
#
# Epoch 00209: val_loss improved from 0.19675 to 0.19664, saving model to ./model/209-0.1966.hdf5
#
# Epoch 00210: val_loss improved from 0.19664 to 0.19649, saving model to ./model/210-0.1965.hdf5
#
# Epoch 00211: val_loss improved from 0.19649 to 0.19570, saving model to ./model/211-0.1957.hdf5
#
# Epoch 00212: val_loss improved from 0.19570 to 0.19549, saving model to ./model/212-0.1955.hdf5
#
# Epoch 00213: val_loss did not improve from 0.19549
#
# Epoch 00214: val_loss improved from 0.19549 to 0.19501, saving model to ./model/214-0.1950.hdf5
#
# Epoch 00215: val_loss improved from 0.19501 to 0.19487, saving model to ./model/215-0.1949.hdf5
#
# Epoch 00216: val_loss improved from 0.19487 to 0.19454, saving model to ./model/216-0.1945.hdf5
#
# Epoch 00217: val_loss improved from 0.19454 to 0.19391, saving model to ./model/217-0.1939.hdf5
#
# Epoch 00218: val_loss improved from 0.19391 to 0.19326, saving model to ./model/218-0.1933.hdf5
#
# Epoch 00219: val_loss improved from 0.19326 to 0.19283, saving model to ./model/219-0.1928.hdf5
#
# Epoch 00220: val_loss improved from 0.19283 to 0.19252, saving model to ./model/220-0.1925.hdf5
#
# Epoch 00221: val_loss improved from 0.19252 to 0.19212, saving model to ./model/221-0.1921.hdf5
#
# Epoch 00222: val_loss improved from 0.19212 to 0.19184, saving model to ./model/222-0.1918.hdf5
#
# Epoch 00223: val_loss improved from 0.19184 to 0.19136, saving model to ./model/223-0.1914.hdf5
#
# Epoch 00224: val_loss improved from 0.19136 to 0.19095, saving model to ./model/224-0.1910.hdf5
#
# Epoch 00225: val_loss improved from 0.19095 to 0.19031, saving model to ./model/225-0.1903.hdf5
#
# Epoch 00226: val_loss improved from 0.19031 to 0.18957, saving model to ./model/226-0.1896.hdf5
#
# Epoch 00227: val_loss improved from 0.18957 to 0.18916, saving model to ./model/227-0.1892.hdf5
#
# Epoch 00228: val_loss improved from 0.18916 to 0.18885, saving model to ./model/228-0.1889.hdf5
#
# Epoch 00229: val_loss improved from 0.18885 to 0.18823, saving model to ./model/229-0.1882.hdf5
#
# Epoch 00230: val_loss improved from 0.18823 to 0.18765, saving model to ./model/230-0.1877.hdf5
#
# Epoch 00231: val_loss improved from 0.18765 to 0.18731, saving model to ./model/231-0.1873.hdf5
#
# Epoch 00232: val_loss improved from 0.18731 to 0.18696, saving model to ./model/232-0.1870.hdf5
#
# Epoch 00233: val_loss improved from 0.18696 to 0.18663, saving model to ./model/233-0.1866.hdf5
#
# Epoch 00234: val_loss improved from 0.18663 to 0.18635, saving model to ./model/234-0.1864.hdf5
#
# Epoch 00235: val_loss improved from 0.18635 to 0.18589, saving model to ./model/235-0.1859.hdf5
#
# Epoch 00236: val_loss improved from 0.18589 to 0.18546, saving model to ./model/236-0.1855.hdf5
#
# Epoch 00237: val_loss improved from 0.18546 to 0.18536, saving model to ./model/237-0.1854.hdf5
#
# Epoch 00238: val_loss improved from 0.18536 to 0.18513, saving model to ./model/238-0.1851.hdf5
#
# Epoch 00239: val_loss improved from 0.18513 to 0.18456, saving model to ./model/239-0.1846.hdf5
#
# Epoch 00240: val_loss improved from 0.18456 to 0.18451, saving model to ./model/240-0.1845.hdf5
#
# Epoch 00241: val_loss improved from 0.18451 to 0.18438, saving model to ./model/241-0.1844.hdf5
#
# Epoch 00242: val_loss improved from 0.18438 to 0.18346, saving model to ./model/242-0.1835.hdf5
#
# Epoch 00243: val_loss improved from 0.18346 to 0.18301, saving model to ./model/243-0.1830.hdf5
#
# Epoch 00244: val_loss improved from 0.18301 to 0.18235, saving model to ./model/244-0.1823.hdf5
#
# Epoch 00245: val_loss improved from 0.18235 to 0.18195, saving model to ./model/245-0.1819.hdf5
#
# Epoch 00246: val_loss improved from 0.18195 to 0.18172, saving model to ./model/246-0.1817.hdf5
#
# Epoch 00247: val_loss improved from 0.18172 to 0.18143, saving model to ./model/247-0.1814.hdf5
#
# Epoch 00248: val_loss improved from 0.18143 to 0.18132, saving model to ./model/248-0.1813.hdf5
#
# Epoch 00249: val_loss improved from 0.18132 to 0.18069, saving model to ./model/249-0.1807.hdf5
#
# Epoch 00250: val_loss improved from 0.18069 to 0.18009, saving model to ./model/250-0.1801.hdf5
#
# Epoch 00251: val_loss improved from 0.18009 to 0.17967, saving model to ./model/251-0.1797.hdf5
#
# Epoch 00252: val_loss improved from 0.17967 to 0.17918, saving model to ./model/252-0.1792.hdf5
#
# Epoch 00253: val_loss improved from 0.17918 to 0.17849, saving model to ./model/253-0.1785.hdf5
#
# Epoch 00254: val_loss improved from 0.17849 to 0.17772, saving model to ./model/254-0.1777.hdf5
#
# Epoch 00255: val_loss improved from 0.17772 to 0.17744, saving model to ./model/255-0.1774.hdf5
#
# Epoch 00256: val_loss improved from 0.17744 to 0.17740, saving model to ./model/256-0.1774.hdf5
#
# Epoch 00257: val_loss improved from 0.17740 to 0.17694, saving model to ./model/257-0.1769.hdf5
#
# Epoch 00258: val_loss improved from 0.17694 to 0.17648, saving model to ./model/258-0.1765.hdf5
#
# Epoch 00259: val_loss improved from 0.17648 to 0.17629, saving model to ./model/259-0.1763.hdf5
#
# Epoch 00260: val_loss improved from 0.17629 to 0.17592, saving model to ./model/260-0.1759.hdf5
#
# Epoch 00261: val_loss improved from 0.17592 to 0.17559, saving model to ./model/261-0.1756.hdf5
#
# Epoch 00262: val_loss improved from 0.17559 to 0.17500, saving model to ./model/262-0.1750.hdf5
#
# Epoch 00263: val_loss improved from 0.17500 to 0.17473, saving model to ./model/263-0.1747.hdf5
#
# Epoch 00264: val_loss did not improve from 0.17473
#
# Epoch 00265: val_loss improved from 0.17473 to 0.17414, saving model to ./model/265-0.1741.hdf5
#
# Epoch 00266: val_loss improved from 0.17414 to 0.17361, saving model to ./model/266-0.1736.hdf5
#
# Epoch 00267: val_loss improved from 0.17361 to 0.17327, saving model to ./model/267-0.1733.hdf5
#
# Epoch 00268: val_loss improved from 0.17327 to 0.17266, saving model to ./model/268-0.1727.hdf5
#
# Epoch 00269: val_loss did not improve from 0.17266
#
# Epoch 00270: val_loss improved from 0.17266 to 0.17249, saving model to ./model/270-0.1725.hdf5
#
# Epoch 00271: val_loss did not improve from 0.17249
#
# Epoch 00272: val_loss improved from 0.17249 to 0.17239, saving model to ./model/272-0.1724.hdf5
#
# Epoch 00273: val_loss improved from 0.17239 to 0.17152, saving model to ./model/273-0.1715.hdf5
#
# Epoch 00274: val_loss improved from 0.17152 to 0.17075, saving model to ./model/274-0.1708.hdf5
#
# Epoch 00275: val_loss improved from 0.17075 to 0.17021, saving model to ./model/275-0.1702.hdf5
#
# Epoch 00276: val_loss improved from 0.17021 to 0.16984, saving model to ./model/276-0.1698.hdf5
#
# Epoch 00277: val_loss improved from 0.16984 to 0.16939, saving model to ./model/277-0.1694.hdf5
#
# Epoch 00278: val_loss improved from 0.16939 to 0.16896, saving model to ./model/278-0.1690.hdf5
#
# Epoch 00279: val_loss improved from 0.16896 to 0.16870, saving model to ./model/279-0.1687.hdf5
#
# Epoch 00280: val_loss improved from 0.16870 to 0.16834, saving model to ./model/280-0.1683.hdf5
#
# Epoch 00281: val_loss improved from 0.16834 to 0.16802, saving model to ./model/281-0.1680.hdf5
#
# Epoch 00282: val_loss did not improve from 0.16802
#
# Epoch 00283: val_loss improved from 0.16802 to 0.16761, saving model to ./model/283-0.1676.hdf5
#
# Epoch 00284: val_loss did not improve from 0.16761
#
# Epoch 00285: val_loss improved from 0.16761 to 0.16750, saving model to ./model/285-0.1675.hdf5
#
# Epoch 00286: val_loss improved from 0.16750 to 0.16730, saving model to ./model/286-0.1673.hdf5
#
# Epoch 00287: val_loss improved from 0.16730 to 0.16686, saving model to ./model/287-0.1669.hdf5
# Epoch 00288: val_loss improved from 0.16686 to 0.16641, saving model to ./model/288-0.1664.hdf5
#
# Epoch 00289: val_loss improved from 0.16641 to 0.16604, saving model to ./model/289-0.1660.hdf5
#
# Epoch 00290: val_loss improved from 0.16604 to 0.16600, saving model to ./model/290-0.1660.hdf5
#
# Epoch 00291: val_loss did not improve from 0.16600
#
# Epoch 00292: val_loss improved from 0.16600 to 0.16456, saving model to ./model/292-0.1646.hdf5
#
# Epoch 00293: val_loss improved from 0.16456 to 0.16439, saving model to ./model/293-0.1644.hdf5
#
# Epoch 00294: val_loss improved from 0.16439 to 0.16400, saving model to ./model/294-0.1640.hdf5
#
# Epoch 00295: val_loss improved from 0.16400 to 0.16365, saving model to ./model/295-0.1636.hdf5
#
# Epoch 00296: val_loss improved from 0.16365 to 0.16358, saving model to ./model/296-0.1636.hdf5
#
# Epoch 00297: val_loss improved from 0.16358 to 0.16351, saving model to ./model/297-0.1635.hdf5
#
# Epoch 00298: val_loss improved from 0.16351 to 0.16324, saving model to ./model/298-0.1632.hdf5
#
# Epoch 00299: val_loss improved from 0.16324 to 0.16314, saving model to ./model/299-0.1631.hdf5
#
# Epoch 00300: val_loss improved from 0.16314 to 0.16289, saving model to ./model/300-0.1629.hdf5
#
# Epoch 00301: val_loss improved from 0.16289 to 0.16269, saving model to ./model/301-0.1627.hdf5
#
# Epoch 00302: val_loss improved from 0.16269 to 0.16204, saving model to ./model/302-0.1620.hdf5
#
# Epoch 00303: val_loss improved from 0.16204 to 0.16133, saving model to ./model/303-0.1613.hdf5
#
# Epoch 00304: val_loss improved from 0.16133 to 0.16101, saving model to ./model/304-0.1610.hdf5
#
# Epoch 00305: val_loss improved from 0.16101 to 0.16007, saving model to ./model/305-0.1601.hdf5
#
# Epoch 00306: val_loss improved from 0.16007 to 0.15882, saving model to ./model/306-0.1588.hdf5
#
# Epoch 00307: val_loss improved from 0.15882 to 0.15860, saving model to ./model/307-0.1586.hdf5
#
# Epoch 00308: val_loss improved from 0.15860 to 0.15848, saving model to ./model/308-0.1585.hdf5
#
# Epoch 00309: val_loss did not improve from 0.15848
#
# Epoch 00310: val_loss did not improve from 0.15848
#
# Epoch 00311: val_loss improved from 0.15848 to 0.15771, saving model to ./model/311-0.1577.hdf5
#
# Epoch 00312: val_loss improved from 0.15771 to 0.15766, saving model to ./model/312-0.1577.hdf5
#
# Epoch 00313: val_loss improved from 0.15766 to 0.15761, saving model to ./model/313-0.1576.hdf5
#
# Epoch 00314: val_loss did not improve from 0.15761
#
# Epoch 00315: val_loss did not improve from 0.15761
#
# Epoch 00316: val_loss did not improve from 0.15761
#
# Epoch 00317: val_loss did not improve from 0.15761
#
# Epoch 00318: val_loss did not improve from 0.15761
#
# Epoch 00319: val_loss did not improve from 0.15761
#
# Epoch 00320: val_loss did not improve from 0.15761
#
# Epoch 00321: val_loss improved from 0.15761 to 0.15666, saving model to ./model/321-0.1567.hdf5
#
# Epoch 00322: val_loss improved from 0.15666 to 0.15594, saving model to ./model/322-0.1559.hdf5
#
# Epoch 00323: val_loss improved from 0.15594 to 0.15565, saving model to ./model/323-0.1556.hdf5
#
# Epoch 00324: val_loss improved from 0.15565 to 0.15512, saving model to ./model/324-0.1551.hdf5
#
# Epoch 00325: val_loss improved from 0.15512 to 0.15465, saving model to ./model/325-0.1547.hdf5
#
# Epoch 00326: val_loss improved from 0.15465 to 0.15419, saving model to ./model/326-0.1542.hdf5
#
# Epoch 00327: val_loss improved from 0.15419 to 0.15370, saving model to ./model/327-0.1537.hdf5
#
# Epoch 00328: val_loss improved from 0.15370 to 0.15355, saving model to ./model/328-0.1536.hdf5
#
# Epoch 00329: val_loss improved from 0.15355 to 0.15255, saving model to ./model/329-0.1526.hdf5
#
# Epoch 00330: val_loss improved from 0.15255 to 0.15158, saving model to ./model/330-0.1516.hdf5
#
# Epoch 00331: val_loss improved from 0.15158 to 0.15096, saving model to ./model/331-0.1510.hdf5
#
# Epoch 00332: val_loss improved from 0.15096 to 0.15062, saving model to ./model/332-0.1506.hdf5
#
# Epoch 00333: val_loss did not improve from 0.15062
#
# Epoch 00334: val_loss did not improve from 0.15062
#
# Epoch 00335: val_loss did not improve from 0.15062
#
# Epoch 00336: val_loss did not improve from 0.15062
#
# Epoch 00337: val_loss did not improve from 0.15062
#
# Epoch 00338: val_loss did not improve from 0.15062
#
# Epoch 00339: val_loss did not improve from 0.15062
#
# Epoch 00340: val_loss did not improve from 0.15062
#
# Epoch 00341: val_loss improved from 0.15062 to 0.14927, saving model to ./model/341-0.1493.hdf5
#
# Epoch 00342: val_loss improved from 0.14927 to 0.14871, saving model to ./model/342-0.1487.hdf5
#
# Epoch 00343: val_loss improved from 0.14871 to 0.14778, saving model to ./model/343-0.1478.hdf5
#
# Epoch 00344: val_loss did not improve from 0.14778
#
# Epoch 00345: val_loss did not improve from 0.14778
#
# Epoch 00346: val_loss did not improve from 0.14778
#
# Epoch 00347: val_loss did not improve from 0.14778
#
# Epoch 00348: val_loss improved from 0.14778 to 0.14721, saving model to ./model/348-0.1472.hdf5
#
# Epoch 00349: val_loss improved from 0.14721 to 0.14708, saving model to ./model/349-0.1471.hdf5
#
# Epoch 00350: val_loss did not improve from 0.14708
#
# Epoch 00351: val_loss did not improve from 0.14708
#
# Epoch 00352: val_loss improved from 0.14708 to 0.14693, saving model to ./model/352-0.1469.hdf5
#
# Epoch 00353: val_loss did not improve from 0.14693
#
# Epoch 00354: val_loss did not improve from 0.14693
#
# Epoch 00355: val_loss did not improve from 0.14693
#
# Epoch 00356: val_loss did not improve from 0.14693
#
# Epoch 00357: val_loss improved from 0.14693 to 0.14597, saving model to ./model/357-0.1460.hdf5
#
# Epoch 00358: val_loss improved from 0.14597 to 0.14497, saving model to ./model/358-0.1450.hdf5
#
# Epoch 00359: val_loss improved from 0.14497 to 0.14435, saving model to ./model/359-0.1444.hdf5
#
# Epoch 00360: val_loss improved from 0.14435 to 0.14370, saving model to ./model/360-0.1437.hdf5
#
# Epoch 00361: val_loss did not improve from 0.14370
#
# Epoch 00362: val_loss improved from 0.14370 to 0.14252, saving model to ./model/362-0.1425.hdf5
#
# Epoch 00363: val_loss improved from 0.14252 to 0.14217, saving model to ./model/363-0.1422.hdf5
#
# Epoch 00364: val_loss did not improve from 0.14217
#
# Epoch 00365: val_loss improved from 0.14217 to 0.14115, saving model to ./model/365-0.1412.hdf5
#
# Epoch 00366: val_loss improved from 0.14115 to 0.14100, saving model to ./model/366-0.1410.hdf5
#
# Epoch 00367: val_loss did not improve from 0.14100
#
# Epoch 00368: val_loss did not improve from 0.14100
#
# Epoch 00369: val_loss did not improve from 0.14100
#
# Epoch 00370: val_loss did not improve from 0.14100
#
# Epoch 00371: val_loss did not improve from 0.14100
#
# Epoch 00372: val_loss did not improve from 0.14100
#
# Epoch 00373: val_loss did not improve from 0.14100
#
# Epoch 00374: val_loss did not improve from 0.14100
#
# Epoch 00375: val_loss improved from 0.14100 to 0.14036, saving model to ./model/375-0.1404.hdf5
#
# Epoch 00376: val_loss improved from 0.14036 to 0.13871, saving model to ./model/376-0.1387.hdf5
#
# Epoch 00377: val_loss improved from 0.13871 to 0.13786, saving model to ./model/377-0.1379.hdf5
#
# Epoch 00378: val_loss did not improve from 0.13786
#
# Epoch 00379: val_loss did not improve from 0.13786
#
# Epoch 00380: val_loss did not improve from 0.13786
#
# Epoch 00381: val_loss improved from 0.13786 to 0.13694, saving model to ./model/381-0.1369.hdf5
#
# Epoch 00382: val_loss improved from 0.13694 to 0.13680, saving model to ./model/382-0.1368.hdf5
#
# Epoch 00383: val_loss did not improve from 0.13680
#
# Epoch 00384: val_loss did not improve from 0.13680
#
# Epoch 00385: val_loss did not improve from 0.13680
#
# Epoch 00386: val_loss did not improve from 0.13680
#
# Epoch 00387: val_loss did not improve from 0.13680
#
# Epoch 00388: val_loss improved from 0.13680 to 0.13660, saving model to ./model/388-0.1366.hdf5
#
# Epoch 00389: val_loss improved from 0.13660 to 0.13635, saving model to ./model/389-0.1364.hdf5
#
# Epoch 00390: val_loss improved from 0.13635 to 0.13597, saving model to ./model/390-0.1360.hdf5
#
# Epoch 00391: val_loss improved from 0.13597 to 0.13556, saving model to ./model/391-0.1356.hdf5
#
# Epoch 00392: val_loss improved from 0.13556 to 0.13539, saving model to ./model/392-0.1354.hdf5
#
# Epoch 00393: val_loss improved from 0.13539 to 0.13494, saving model to ./model/393-0.1349.hdf5
#
# Epoch 00394: val_loss did not improve from 0.13494
#
# Epoch 00395: val_loss improved from 0.13494 to 0.13475, saving model to ./model/395-0.1347.hdf5
# Epoch 00396: val_loss improved from 0.13475 to 0.13441, saving model to ./model/396-0.1344.hdf5
#
# Epoch 00397: val_loss improved from 0.13441 to 0.13438, saving model to ./model/397-0.1344.hdf5
#
# Epoch 00398: val_loss did not improve from 0.13438
#
# Epoch 00399: val_loss improved from 0.13438 to 0.13433, saving model to ./model/399-0.1343.hdf5
#
# Epoch 00400: val_loss improved from 0.13433 to 0.13431, saving model to ./model/400-0.1343.hdf5
#
# Epoch 00401: val_loss improved from 0.13431 to 0.13375, saving model to ./model/401-0.1337.hdf5
#
# Epoch 00402: val_loss did not improve from 0.13375
#
# Epoch 00403: val_loss did not improve from 0.13375
#
# Epoch 00404: val_loss did not improve from 0.13375
#
# Epoch 00405: val_loss did not improve from 0.13375
#
# Epoch 00406: val_loss improved from 0.13375 to 0.13326, saving model to ./model/406-0.1333.hdf5
#
# Epoch 00407: val_loss improved from 0.13326 to 0.13163, saving model to ./model/407-0.1316.hdf5
#
# Epoch 00408: val_loss improved from 0.13163 to 0.13123, saving model to ./model/408-0.1312.hdf5
#
# Epoch 00409: val_loss improved from 0.13123 to 0.13101, saving model to ./model/409-0.1310.hdf5
#
# Epoch 00410: val_loss improved from 0.13101 to 0.13101, saving model to ./model/410-0.1310.hdf5
#
# Epoch 00411: val_loss improved from 0.13101 to 0.13036, saving model to ./model/411-0.1304.hdf5
#
# Epoch 00412: val_loss did not improve from 0.13036
#
# Epoch 00413: val_loss did not improve from 0.13036
#
# Epoch 00414: val_loss did not improve from 0.13036
#
# Epoch 00415: val_loss improved from 0.13036 to 0.13011, saving model to ./model/415-0.1301.hdf5
#
# Epoch 00416: val_loss improved from 0.13011 to 0.13002, saving model to ./model/416-0.1300.hdf5
#
# Epoch 00417: val_loss did not improve from 0.13002
#
# Epoch 00418: val_loss did not improve from 0.13002
#
# Epoch 00419: val_loss improved from 0.13002 to 0.12965, saving model to ./model/419-0.1296.hdf5
#
# Epoch 00420: val_loss did not improve from 0.12965
#
# Epoch 00421: val_loss did not improve from 0.12965
#
# Epoch 00422: val_loss did not improve from 0.12965
#
# Epoch 00423: val_loss did not improve from 0.12965
#
# Epoch 00424: val_loss did not improve from 0.12965
#
# Epoch 00425: val_loss did not improve from 0.12965
#
# Epoch 00426: val_loss did not improve from 0.12965
#
# Epoch 00427: val_loss did not improve from 0.12965
#
# Epoch 00428: val_loss did not improve from 0.12965
#
# Epoch 00429: val_loss did not improve from 0.12965
#
# Epoch 00430: val_loss did not improve from 0.12965
#
# Epoch 00431: val_loss did not improve from 0.12965
#
# Epoch 00432: val_loss did not improve from 0.12965
#
# Epoch 00433: val_loss did not improve from 0.12965
#
# Epoch 00434: val_loss did not improve from 0.12965
#
# Epoch 00435: val_loss improved from 0.12965 to 0.12912, saving model to ./model/435-0.1291.hdf5
#
# Epoch 00436: val_loss improved from 0.12912 to 0.12823, saving model to ./model/436-0.1282.hdf5
#
# Epoch 00437: val_loss did not improve from 0.12823
#
# Epoch 00438: val_loss did not improve from 0.12823
#
# Epoch 00439: val_loss improved from 0.12823 to 0.12704, saving model to ./model/439-0.1270.hdf5
#
# Epoch 00440: val_loss improved from 0.12704 to 0.12634, saving model to ./model/440-0.1263.hdf5
#
# Epoch 00441: val_loss did not improve from 0.12634
#
# Epoch 00442: val_loss did not improve from 0.12634
#
# Epoch 00443: val_loss did not improve from 0.12634
#
# Epoch 00444: val_loss improved from 0.12634 to 0.12374, saving model to ./model/444-0.1237.hdf5
#
# Epoch 00445: val_loss improved from 0.12374 to 0.12321, saving model to ./model/445-0.1232.hdf5
#
# Epoch 00446: val_loss did not improve from 0.12321
#
# Epoch 00447: val_loss did not improve from 0.12321
#
# Epoch 00448: val_loss improved from 0.12321 to 0.12320, saving model to ./model/448-0.1232.hdf5
#
# Epoch 00449: val_loss improved from 0.12320 to 0.12104, saving model to ./model/449-0.1210.hdf5
#
# Epoch 00450: val_loss improved from 0.12104 to 0.11928, saving model to ./model/450-0.1193.hdf5
#
# Epoch 00451: val_loss did not improve from 0.11928
#
# Epoch 00452: val_loss did not improve from 0.11928
#
# Epoch 00453: val_loss improved from 0.11928 to 0.11642, saving model to ./model/453-0.1164.hdf5
#
# Epoch 00454: val_loss did not improve from 0.11642
#
# Epoch 00455: val_loss did not improve from 0.11642
#
# Epoch 00456: val_loss did not improve from 0.11642
#
# Epoch 00457: val_loss did not improve from 0.11642
#
# Epoch 00458: val_loss did not improve from 0.11642
#
# Epoch 00459: val_loss did not improve from 0.11642
#
# Epoch 00460: val_loss improved from 0.11642 to 0.11360, saving model to ./model/460-0.1136.hdf5
#
# Epoch 00461: val_loss improved from 0.11360 to 0.11305, saving model to ./model/461-0.1130.hdf5
#
# Epoch 00462: val_loss did not improve from 0.11305
#
# Epoch 00463: val_loss did not improve from 0.11305
#
# Epoch 00464: val_loss improved from 0.11305 to 0.11240, saving model to ./model/464-0.1124.hdf5
#
# Epoch 00465: val_loss improved from 0.11240 to 0.11202, saving model to ./model/465-0.1120.hdf5
#
# Epoch 00466: val_loss did not improve from 0.11202
#
# Epoch 00467: val_loss did not improve from 0.11202
#
# Epoch 00468: val_loss did not improve from 0.11202
#
# Epoch 00469: val_loss improved from 0.11202 to 0.11191, saving model to ./model/469-0.1119.hdf5
#
# Epoch 00470: val_loss did not improve from 0.11191
#
# Epoch 00471: val_loss did not improve from 0.11191
#
# Epoch 00472: val_loss improved from 0.11191 to 0.11130, saving model to ./model/472-0.1113.hdf5
#
# Epoch 00473: val_loss did not improve from 0.11130
#
# Epoch 00474: val_loss did not improve from 0.11130
#
# Epoch 00475: val_loss did not improve from 0.11130
#
# Epoch 00476: val_loss improved from 0.11130 to 0.10843, saving model to ./model/476-0.1084.hdf5
#
# Epoch 00477: val_loss did not improve from 0.10843
#
# Epoch 00478: val_loss did not improve from 0.10843
#
# Epoch 00479: val_loss did not improve from 0.10843
#
# Epoch 00480: val_loss improved from 0.10843 to 0.10661, saving model to ./model/480-0.1066.hdf5
#
# Epoch 00481: val_loss did not improve from 0.10661
#
# Epoch 00482: val_loss did not improve from 0.10661
#
# Epoch 00483: val_loss did not improve from 0.10661
#
# Epoch 00484: val_loss did not improve from 0.10661
#
# Epoch 00485: val_loss did not improve from 0.10661
#
# Epoch 00486: val_loss did not improve from 0.10661
#
# Epoch 00487: val_loss improved from 0.10661 to 0.10639, saving model to ./model/487-0.1064.hdf5
#
# Epoch 00488: val_loss did not improve from 0.10639
#
# Epoch 00489: val_loss did not improve from 0.10639
#
# Epoch 00490: val_loss did not improve from 0.10639
#
# Epoch 00491: val_loss improved from 0.10639 to 0.10558, saving model to ./model/491-0.1056.hdf5
#
# Epoch 00492: val_loss improved from 0.10558 to 0.10537, saving model to ./model/492-0.1054.hdf5
#
# Epoch 00493: val_loss did not improve from 0.10537
#
# Epoch 00494: val_loss did not improve from 0.10537
#
# Epoch 00495: val_loss did not improve from 0.10537
#
# Epoch 00496: val_loss did not improve from 0.10537
#
# Epoch 00497: val_loss did not improve from 0.10537
#
# Epoch 00498: val_loss did not improve from 0.10537
#
# Epoch 00499: val_loss did not improve from 0.10537
#
# Epoch 00500: val_loss improved from 0.10537 to 0.10501, saving model to ./model/500-0.1050.hdf5
#
# Epoch 00501: val_loss did not improve from 0.10501
#
# Epoch 00502: val_loss did not improve from 0.10501
#
# Epoch 00503: val_loss improved from 0.10501 to 0.10470, saving model to ./model/503-0.1047.hdf5
#
# Epoch 00504: val_loss improved from 0.10470 to 0.10281, saving model to ./model/504-0.1028.hdf5
#
# Epoch 00505: val_loss did not improve from 0.10281
#
# Epoch 00506: val_loss did not improve from 0.10281
#
# Epoch 00507: val_loss did not improve from 0.10281
#
# Epoch 00508: val_loss improved from 0.10281 to 0.10113, saving model to ./model/508-0.1011.hdf5
#
# Epoch 00509: val_loss did not improve from 0.10113
#
# Epoch 00510: val_loss did not improve from 0.10113
#
# Epoch 00511: val_loss did not improve from 0.10113
#
# Epoch 00512: val_loss improved from 0.10113 to 0.10041, saving model to ./model/512-0.1004.hdf5
#
# Epoch 00513: val_loss did not improve from 0.10041
#
# Epoch 00514: val_loss did not improve from 0.10041
#
# Epoch 00515: val_loss did not improve from 0.10041
#
# Epoch 00516: val_loss improved from 0.10041 to 0.10022, saving model to ./model/516-0.1002.hdf5
#
# Epoch 00517: val_loss did not improve from 0.10022
#
# Epoch 00518: val_loss did not improve from 0.10022
#
# Epoch 00519: val_loss did not improve from 0.10022
#
# Epoch 00520: val_loss improved from 0.10022 to 0.09965, saving model to ./model/520-0.0997.hdf5
#
# Epoch 00521: val_loss did not improve from 0.09965
#
# Epoch 00522: val_loss did not improve from 0.09965
#
# Epoch 00523: val_loss did not improve from 0.09965
# Epoch 00524: val_loss did not improve from 0.09965
#
# Epoch 00525: val_loss improved from 0.09965 to 0.09955, saving model to ./model/525-0.0996.hdf5
#
# Epoch 00526: val_loss did not improve from 0.09955
#
# Epoch 00527: val_loss did not improve from 0.09955
#
# Epoch 00528: val_loss did not improve from 0.09955
#
# Epoch 00529: val_loss improved from 0.09955 to 0.09854, saving model to ./model/529-0.0985.hdf5
#
# Epoch 00530: val_loss did not improve from 0.09854
#
# Epoch 00531: val_loss did not improve from 0.09854
#
# Epoch 00532: val_loss did not improve from 0.09854
#
# Epoch 00533: val_loss improved from 0.09854 to 0.09739, saving model to ./model/533-0.0974.hdf5
#
# Epoch 00534: val_loss improved from 0.09739 to 0.09674, saving model to ./model/534-0.0967.hdf5
#
# Epoch 00535: val_loss did not improve from 0.09674
#
# Epoch 00536: val_loss did not improve from 0.09674
#
# Epoch 00537: val_loss did not improve from 0.09674
#
# Epoch 00538: val_loss did not improve from 0.09674
#
# Epoch 00539: val_loss did not improve from 0.09674
#
# Epoch 00540: val_loss did not improve from 0.09674
#
# Epoch 00541: val_loss did not improve from 0.09674
#
# Epoch 00542: val_loss improved from 0.09674 to 0.09629, saving model to ./model/542-0.0963.hdf5
#
# Epoch 00543: val_loss improved from 0.09629 to 0.09575, saving model to ./model/543-0.0957.hdf5
#
# Epoch 00544: val_loss did not improve from 0.09575
#
# Epoch 00545: val_loss did not improve from 0.09575
#
# Epoch 00546: val_loss did not improve from 0.09575
#
# Epoch 00547: val_loss improved from 0.09575 to 0.09415, saving model to ./model/547-0.0941.hdf5
#
# Epoch 00548: val_loss did not improve from 0.09415
#
# Epoch 00549: val_loss did not improve from 0.09415
#
# Epoch 00550: val_loss did not improve from 0.09415
#
# Epoch 00551: val_loss improved from 0.09415 to 0.09378, saving model to ./model/551-0.0938.hdf5
#
# Epoch 00552: val_loss did not improve from 0.09378
#
# Epoch 00553: val_loss did not improve from 0.09378
#
# Epoch 00554: val_loss did not improve from 0.09378
#
# Epoch 00555: val_loss improved from 0.09378 to 0.09308, saving model to ./model/555-0.0931.hdf5
#
# Epoch 00556: val_loss did not improve from 0.09308
#
# Epoch 00557: val_loss did not improve from 0.09308
#
# Epoch 00558: val_loss did not improve from 0.09308
#
# Epoch 00559: val_loss improved from 0.09308 to 0.09235, saving model to ./model/559-0.0923.hdf5
#
# Epoch 00560: val_loss did not improve from 0.09235
#
# Epoch 00561: val_loss did not improve from 0.09235
#
# Epoch 00562: val_loss did not improve from 0.09235
#
# Epoch 00563: val_loss improved from 0.09235 to 0.09069, saving model to ./model/563-0.0907.hdf5
#
# Epoch 00564: val_loss did not improve from 0.09069
#
# Epoch 00565: val_loss did not improve from 0.09069
#
# Epoch 00566: val_loss did not improve from 0.09069
#
# Epoch 00567: val_loss did not improve from 0.09069
#
# Epoch 00568: val_loss did not improve from 0.09069
#
# Epoch 00569: val_loss did not improve from 0.09069
#
# Epoch 00570: val_loss did not improve from 0.09069
#
# Epoch 00571: val_loss did not improve from 0.09069
#
# Epoch 00572: val_loss improved from 0.09069 to 0.08982, saving model to ./model/572-0.0898.hdf5
#
# Epoch 00573: val_loss did not improve from 0.08982
#
# Epoch 00574: val_loss did not improve from 0.08982
#
# Epoch 00575: val_loss did not improve from 0.08982
#
# Epoch 00576: val_loss did not improve from 0.08982
#
# Epoch 00577: val_loss improved from 0.08982 to 0.08954, saving model to ./model/577-0.0895.hdf5
#
# Epoch 00578: val_loss did not improve from 0.08954
#
# Epoch 00579: val_loss did not improve from 0.08954
#
# Epoch 00580: val_loss did not improve from 0.08954
#
# Epoch 00581: val_loss did not improve from 0.08954
#
# Epoch 00582: val_loss did not improve from 0.08954
#
# Epoch 00583: val_loss improved from 0.08954 to 0.08861, saving model to ./model/583-0.0886.hdf5
#
# Epoch 00584: val_loss improved from 0.08861 to 0.08855, saving model to ./model/584-0.0885.hdf5
#
# Epoch 00585: val_loss did not improve from 0.08855
#
# Epoch 00586: val_loss did not improve from 0.08855
#
# Epoch 00587: val_loss improved from 0.08855 to 0.08705, saving model to ./model/587-0.0871.hdf5
#
# Epoch 00588: val_loss did not improve from 0.08705
#
# Epoch 00589: val_loss did not improve from 0.08705
#
# Epoch 00590: val_loss did not improve from 0.08705
#
# Epoch 00591: val_loss improved from 0.08705 to 0.08598, saving model to ./model/591-0.0860.hdf5
#
# Epoch 00592: val_loss did not improve from 0.08598
#
# Epoch 00593: val_loss did not improve from 0.08598
#
# Epoch 00594: val_loss did not improve from 0.08598
#
# Epoch 00595: val_loss did not improve from 0.08598
#
# Epoch 00596: val_loss did not improve from 0.08598
#
# Epoch 00597: val_loss did not improve from 0.08598
#
# Epoch 00598: val_loss did not improve from 0.08598
#
# Epoch 00599: val_loss improved from 0.08598 to 0.08377, saving model to ./model/599-0.0838.hdf5
#
# Epoch 00600: val_loss did not improve from 0.08377
#
# Epoch 00601: val_loss did not improve from 0.08377
#
# Epoch 00602: val_loss did not improve from 0.08377
#
# Epoch 00603: val_loss did not improve from 0.08377
#
# Epoch 00604: val_loss did not improve from 0.08377
#
# Epoch 00605: val_loss did not improve from 0.08377
#
# Epoch 00606: val_loss did not improve from 0.08377
#
# Epoch 00607: val_loss did not improve from 0.08377
#
# Epoch 00608: val_loss did not improve from 0.08377
#
# Epoch 00609: val_loss improved from 0.08377 to 0.08347, saving model to ./model/609-0.0835.hdf5
#
# Epoch 00610: val_loss did not improve from 0.08347
#
# Epoch 00611: val_loss did not improve from 0.08347
#
# Epoch 00612: val_loss improved from 0.08347 to 0.08242, saving model to ./model/612-0.0824.hdf5
#
# Epoch 00613: val_loss improved from 0.08242 to 0.08201, saving model to ./model/613-0.0820.hdf5
#
# Epoch 00614: val_loss did not improve from 0.08201
#
# Epoch 00615: val_loss did not improve from 0.08201
#
# Epoch 00616: val_loss did not improve from 0.08201
#
# Epoch 00617: val_loss did not improve from 0.08201
#
# ...
#
# Epoch 01139: val_loss did not improve from 0.04038
#
# Epoch 01140: val_loss did not improve from 0.04038
#
# Epoch 01141: val_loss improved from 0.04038 to 0.03783, saving model to ./model/1141-0.0378.hdf5
#
# Epoch 01142: val_loss did not improve from 0.03783
#
# Epoch 01143: val_loss did not improve from 0.03783
#
# Epoch 01144: val_loss improved from 0.03783 to 0.03748, saving model to ./model/1144-0.0375.hdf5
#
# Epoch 01145: val_loss did not improve from 0.03748
#
# Epoch 01146: val_loss did not improve from 0.03748
#
# Epoch 01147: val_loss did not improve from 0.03748
#
# Epoch 01148: val_loss did not improve from 0.03748
#
# Epoch 01149: val_loss did not improve from 0.03748
#
# Epoch 01150: val_loss did not improve from 0.03748
#
# Epoch 01151: val_loss did not improve from 0.03748
#
# Epoch 01152: val_loss improved from 0.03748 to 0.03657, saving model to ./model/1152-0.0366.hdf5
#
# Epoch 01153: val_loss did not improve from 0.03657
#
# Epoch 01154: val_loss did not improve from 0.03657
#
# Epoch 01155: val_loss did not improve from 0.03657
#
# Epoch 01156: val_loss did not improve from 0.03657
#
# Epoch 01157: val_loss did not improve from 0.03657
#
# Epoch 01158: val_loss did not improve from 0.03657
#
# Epoch 01159: val_loss did not improve from 0.03657
#
# Epoch 01160: val_loss did not improve from 0.03657
#
# Epoch 01161: val_loss did not improve from 0.03657
#
# Epoch 01162: val_loss did not improve from 0.03657
#
# Epoch 01163: val_loss did not improve from 0.03657
#
# Epoch 01164: val_loss did not improve from 0.03657
#
# Epoch 01165: val_loss did not improve from 0.03657
#
# Epoch 01166: val_loss did not improve from 0.03657
#
# Epoch 01167: val_loss did not improve from 0.03657
#
# Epoch 01168: val_loss did not improve from 0.03657
#
# Epoch 01169: val_loss did not improve from 0.03657
#
# Epoch 01170: val_loss did not improve from 0.03657
#
# Epoch 01171: val_loss improved from 0.03657 to 0.03650, saving model to ./model/1171-0.0365.hdf5
#
# Epoch 01172: val_loss did not improve from 0.03650
#
# Epoch 01173: val_loss did not improve from 0.03650
#
# Epoch 01174: val_loss did not improve from 0.03650
#
# Epoch 01175: val_loss did not improve from 0.03650
#
# Epoch 01176: val_loss did not improve from 0.03650
#
# Epoch 01177: val_loss did not improve from 0.03650
#
# Epoch 01178: val_loss did not improve from 0.03650
#
# Epoch 01179: val_loss did not improve from 0.03650
#
# Epoch 01180: val_loss did not improve from 0.03650
#
# Epoch 01181: val_loss did not improve from 0.03650
#
# Epoch 01182: val_loss did not improve from 0.03650
#
# Epoch 01183: val_loss did not improve from 0.03650
#
# Epoch 01184: val_loss did not improve from 0.03650
#
# Epoch 01185: val_loss did not improve from 0.03650
#
# Epoch 01186: val_loss did not improve from 0.03650
#
# Epoch 01187: val_loss did not improve from 0.03650
#
# Epoch 01188: val_loss did not improve from 0.03650
#
# Epoch 01189: val_loss did not improve from 0.03650
#
# Epoch 01190: val_loss did not improve from 0.03650
#
# Epoch 01191: val_loss did not improve from 0.03650
#
# Epoch 01192: val_loss did not improve from 0.03650
#
# Epoch 01193: val_loss did not improve from 0.03650
#
# Epoch 01194: val_loss did not improve from 0.03650
#
# Epoch 01195: val_loss did not improve from 0.03650
#
# Epoch 01196: val_loss did not improve from 0.03650
#
# Epoch 01197: val_loss did not improve from 0.03650
#
# Epoch 01198: val_loss did not improve from 0.03650
#
# Epoch 01199: val_loss did not improve from 0.03650
#
# Epoch 01200: val_loss did not improve from 0.03650
#
# Epoch 01201: val_loss did not improve from 0.03650
#
# Epoch 01202: val_loss did not improve from 0.03650
#
# Epoch 01203: val_loss did not improve from 0.03650
#
# Epoch 01204: val_loss did not improve from 0.03650
#
# Epoch 01205: val_loss improved from 0.03650 to 0.03556, saving model to ./model/1205-0.0356.hdf5
#
# Epoch 01206: val_loss did not improve from 0.03556
#
# Epoch 01207: val_loss did not improve from 0.03556
#
# Epoch 01208: val_loss did not improve from 0.03556
#
# Epoch 01209: val_loss did not improve from 0.03556
#
# Epoch 01210: val_loss did not improve from 0.03556
#
# Epoch 01211: val_loss did not improve from 0.03556
#
# Epoch 01212: val_loss did not improve from 0.03556
#
# Epoch 01213: val_loss did not improve from 0.03556
#
# Epoch 01214: val_loss did not improve from 0.03556
#
# Epoch 01215: val_loss did not improve from 0.03556
#
# Epoch 01216: val_loss did not improve from 0.03556
#
# Epoch 01217: val_loss did not improve from 0.03556
#
# Epoch 01218: val_loss did not improve from 0.03556
#
# Epoch 01219: val_loss did not improve from 0.03556
#
# Epoch 01220: val_loss did not improve from 0.03556
#
# Epoch 01221: val_loss did not improve from 0.03556
#
# Epoch 01222: val_loss did not improve from 0.03556
#
# Epoch 01223: val_loss did not improve from 0.03556
#
# Epoch 01224: val_loss did not improve from 0.03556
#
# Epoch 01225: val_loss did not improve from 0.03556
#
# Epoch 01226: val_loss did not improve from 0.03556
#
# Epoch 01227: val_loss did not improve from 0.03556
#
# Epoch 01228: val_loss did not improve from 0.03556
#
# Epoch 01229: val_loss did not improve from 0.03556
#
# Epoch 01230: val_loss did not improve from 0.03556
#
# Epoch 01231: val_loss did not improve from 0.03556
#
# Epoch 01232: val_loss did not improve from 0.03556
#
# Epoch 01233: val_loss did not improve from 0.03556
#
# Epoch 01234: val_loss did not improve from 0.03556
#
# Epoch 01235: val_loss did not improve from 0.03556
#
# Epoch 01236: val_loss did not improve from 0.03556
#
# Epoch 01237: val_loss did not improve from 0.03556
#
# Epoch 01238: val_loss did not improve from 0.03556
#
# Epoch 01239: val_loss did not improve from 0.03556
#
# Epoch 01240: val_loss did not improve from 0.03556
#
# Epoch 01241: val_loss did not improve from 0.03556
#
# Epoch 01242: val_loss did not improve from 0.03556
#
# Epoch 01243: val_loss improved from 0.03556 to 0.03492, saving model to ./model/1243-0.0349.hdf5
#
# Epoch 01244: val_loss did not improve from 0.03492
#
# Epoch 01245: val_loss did not improve from 0.03492
#
# Epoch 01246: val_loss did not improve from 0.03492
#
# Epoch 01247: val_loss did not improve from 0.03492
#
# Epoch 01248: val_loss did not improve from 0.03492
#
# Epoch 01249: val_loss did not improve from 0.03492
#
# Epoch 01250: val_loss did not improve from 0.03492
#
# Epoch 01251: val_loss did not improve from 0.03492
#
# Epoch 01252: val_loss did not improve from 0.03492
#
# Epoch 01253: val_loss did not improve from 0.03492
#
# Epoch 01254: val_loss did not improve from 0.03492
#
# Epoch 01255: val_loss did not improve from 0.03492
#
# Epoch 01256: val_loss did not improve from 0.03492
#
# Epoch 01257: val_loss did not improve from 0.03492
#
# Epoch 01258: val_loss did not improve from 0.03492
#
# Epoch 01259: val_loss did not improve from 0.03492
#
# Epoch 01260: val_loss did not improve from 0.03492
#
# Epoch 01261: val_loss did not improve from 0.03492
#
# Epoch 01262: val_loss improved from 0.03492 to 0.03454, saving model to ./model/1262-0.0345.hdf5
#
# Epoch 01263: val_loss improved from 0.03454 to 0.03443, saving model to ./model/1263-0.0344.hdf5
#
# Epoch 01264: val_loss did not improve from 0.03443
#
# Epoch 01265: val_loss did not improve from 0.03443
#
# Epoch 01266: val_loss did not improve from 0.03443
#
# Epoch 01267: val_loss did not improve from 0.03443
#
# Epoch 01268: val_loss did not improve from 0.03443
#
# Epoch 01269: val_loss did not improve from 0.03443
#
# Epoch 01270: val_loss did not improve from 0.03443
#
# Epoch 01271: val_loss did not improve from 0.03443
# Epoch 01272: val_loss did not improve from 0.03443
#
# Epoch 01273: val_loss did not improve from 0.03443
#
# Epoch 01274: val_loss did not improve from 0.03443
#
# Epoch 01275: val_loss did not improve from 0.03443
#
# Epoch 01276: val_loss did not improve from 0.03443
#
# Epoch 01277: val_loss did not improve from 0.03443
#
# Epoch 01278: val_loss did not improve from 0.03443
#
# Epoch 01279: val_loss did not improve from 0.03443
#
# Epoch 01280: val_loss did not improve from 0.03443
#
# Epoch 01281: val_loss did not improve from 0.03443
#
# Epoch 01282: val_loss did not improve from 0.03443
#
# Epoch 01283: val_loss did not improve from 0.03443
#
# Epoch 01284: val_loss did not improve from 0.03443
#
# Epoch 01285: val_loss did not improve from 0.03443
#
# Epoch 01286: val_loss improved from 0.03443 to 0.03416, saving model to ./model/1286-0.0342.hdf5
#
# Epoch 01287: val_loss did not improve from 0.03416
#
# Epoch 01288: val_loss did not improve from 0.03416
#
# Epoch 01289: val_loss did not improve from 0.03416
#
# Epoch 01290: val_loss did not improve from 0.03416
#
# Epoch 01291: val_loss did not improve from 0.03416
#
# Epoch 01292: val_loss did not improve from 0.03416
#
# Epoch 01293: val_loss did not improve from 0.03416
#
# Epoch 01294: val_loss did not improve from 0.03416
#
# Epoch 01295: val_loss did not improve from 0.03416
#
# Epoch 01296: val_loss did not improve from 0.03416
#
# Epoch 01297: val_loss did not improve from 0.03416
#
# Epoch 01298: val_loss did not improve from 0.03416
#
# Epoch 01299: val_loss did not improve from 0.03416
#
# Epoch 01300: val_loss did not improve from 0.03416
#
# Epoch 01301: val_loss did not improve from 0.03416
#
# Epoch 01302: val_loss improved from 0.03416 to 0.03393, saving model to ./model/1302-0.0339.hdf5
#
# Epoch 01303: val_loss did not improve from 0.03393
#
# Epoch 01304: val_loss did not improve from 0.03393
#
# Epoch 01305: val_loss did not improve from 0.03393
#
# Epoch 01306: val_loss did not improve from 0.03393
#
# Epoch 01307: val_loss did not improve from 0.03393
#
# Epoch 01308: val_loss did not improve from 0.03393
#
# Epoch 01309: val_loss did not improve from 0.03393
#
# Epoch 01310: val_loss did not improve from 0.03393
#
# Epoch 01311: val_loss did not improve from 0.03393
#
# Epoch 01312: val_loss did not improve from 0.03393
#
# Epoch 01313: val_loss did not improve from 0.03393
#
# Epoch 01314: val_loss did not improve from 0.03393
#
# Epoch 01315: val_loss did not improve from 0.03393
#
# Epoch 01316: val_loss did not improve from 0.03393
#
# Epoch 01317: val_loss did not improve from 0.03393
#
# Epoch 01318: val_loss did not improve from 0.03393
#
# Epoch 01319: val_loss did not improve from 0.03393
#
# Epoch 01320: val_loss did not improve from 0.03393
#
# Epoch 01321: val_loss did not improve from 0.03393
#
# Epoch 01322: val_loss did not improve from 0.03393
#
# Epoch 01323: val_loss did not improve from 0.03393
#
# Epoch 01324: val_loss did not improve from 0.03393
#
# Epoch 01325: val_loss did not improve from 0.03393
#
# Epoch 01326: val_loss did not improve from 0.03393
#
# Epoch 01327: val_loss did not improve from 0.03393
#
# Epoch 01328: val_loss did not improve from 0.03393
#
# Epoch 01329: val_loss did not improve from 0.03393
#
# Epoch 01330: val_loss did not improve from 0.03393
#
# Epoch 01331: val_loss did not improve from 0.03393
#
# Epoch 01332: val_loss improved from 0.03393 to 0.03359, saving model to ./model/1332-0.0336.hdf5
#
# Epoch 01333: val_loss did not improve from 0.03359
#
# Epoch 01334: val_loss did not improve from 0.03359
#
# Epoch 01335: val_loss improved from 0.03359 to 0.03190, saving model to ./model/1335-0.0319.hdf5
#
# Epoch 01336: val_loss did not improve from 0.03190
#
# Epoch 01337: val_loss did not improve from 0.03190
#
# Epoch 01338: val_loss did not improve from 0.03190
#
# Epoch 01339: val_loss did not improve from 0.03190
#
# Epoch 01340: val_loss did not improve from 0.03190
#
# Epoch 01341: val_loss did not improve from 0.03190
#
# Epoch 01342: val_loss did not improve from 0.03190
#
# Epoch 01343: val_loss did not improve from 0.03190
#
# Epoch 01344: val_loss did not improve from 0.03190
#
# Epoch 01345: val_loss did not improve from 0.03190
#
# Epoch 01346: val_loss did not improve from 0.03190
#
# Epoch 01347: val_loss did not improve from 0.03190
#
# Epoch 01348: val_loss did not improve from 0.03190
#
# Epoch 01349: val_loss did not improve from 0.03190
#
# Epoch 01350: val_loss did not improve from 0.03190
#
# Epoch 01351: val_loss did not improve from 0.03190
#
# Epoch 01352: val_loss did not improve from 0.03190
#
# Epoch 01353: val_loss did not improve from 0.03190
#
# Epoch 01354: val_loss did not improve from 0.03190
#
# Epoch 01355: val_loss did not improve from 0.03190
#
# Epoch 01356: val_loss did not improve from 0.03190
#
# Epoch 01357: val_loss did not improve from 0.03190
#
# Epoch 01358: val_loss did not improve from 0.03190
#
# Epoch 01359: val_loss did not improve from 0.03190
#
# Epoch 01360: val_loss did not improve from 0.03190
#
# Epoch 01361: val_loss did not improve from 0.03190
#
# Epoch 01362: val_loss did not improve from 0.03190
#
# Epoch 01363: val_loss did not improve from 0.03190
#
# Epoch 01364: val_loss did not improve from 0.03190
#
# Epoch 01365: val_loss did not improve from 0.03190
#
# Epoch 01366: val_loss did not improve from 0.03190
#
# Epoch 01367: val_loss did not improve from 0.03190
#
# Epoch 01368: val_loss did not improve from 0.03190
#
# Epoch 01369: val_loss did not improve from 0.03190
#
# Epoch 01370: val_loss did not improve from 0.03190
#
# Epoch 01371: val_loss did not improve from 0.03190
#
# Epoch 01372: val_loss did not improve from 0.03190
#
# Epoch 01373: val_loss did not improve from 0.03190
#
# Epoch 01374: val_loss did not improve from 0.03190
#
# Epoch 01375: val_loss did not improve from 0.03190
#
# Epoch 01376: val_loss did not improve from 0.03190
#
# Epoch 01377: val_loss did not improve from 0.03190
#
# Epoch 01378: val_loss did not improve from 0.03190
#
# Epoch 01379: val_loss did not improve from 0.03190
#
# Epoch 01380: val_loss did not improve from 0.03190
#
# Epoch 01381: val_loss did not improve from 0.03190
#
# Epoch 01382: val_loss did not improve from 0.03190
#
# Epoch 01383: val_loss did not improve from 0.03190
#
# Epoch 01384: val_loss did not improve from 0.03190
#
# Epoch 01385: val_loss did not improve from 0.03190
#
# Epoch 01386: val_loss did not improve from 0.03190
#
# Epoch 01387: val_loss did not improve from 0.03190
#
# Epoch 01388: val_loss did not improve from 0.03190
#
# Epoch 01389: val_loss did not improve from 0.03190
#
# Epoch 01390: val_loss did not improve from 0.03190
#
# Epoch 01391: val_loss did not improve from 0.03190
#
# Epoch 01392: val_loss did not improve from 0.03190
#
# Epoch 01393: val_loss did not improve from 0.03190
#
# Epoch 01394: val_loss did not improve from 0.03190
#
# Epoch 01395: val_loss did not improve from 0.03190
#
# Epoch 01396: val_loss did not improve from 0.03190
#
# Epoch 01397: val_loss did not improve from 0.03190
#
# Epoch 01398: val_loss did not improve from 0.03190
#
# Epoch 01399: val_loss did not improve from 0.03190
#
# Epoch 01400: val_loss did not improve from 0.03190
#
# Epoch 01401: val_loss did not improve from 0.03190
#
# Epoch 01402: val_loss did not improve from 0.03190
#
# Epoch 01403: val_loss did not improve from 0.03190
#
# Epoch 01404: val_loss did not improve from 0.03190
#
# Epoch 01405: val_loss did not improve from 0.03190
#
# Epoch 01406: val_loss did not improve from 0.03190
#
# Epoch 01407: val_loss did not improve from 0.03190
#
# Epoch 01408: val_loss did not improve from 0.03190
#
# Epoch 01409: val_loss did not improve from 0.03190
#
# Epoch 01410: val_loss did not improve from 0.03190
#
# Epoch 01411: val_loss did not improve from 0.03190
#
# Epoch 01412: val_loss did not improve from 0.03190
#
# Epoch 01413: val_loss did not improve from 0.03190
#
# Epoch 01414: val_loss did not improve from 0.03190
#
# Epoch 01415: val_loss did not improve from 0.03190
#
# Epoch 01416: val_loss did not improve from 0.03190
#
# Epoch 01417: val_loss did not improve from 0.03190
#
# Epoch 01418: val_loss did not improve from 0.03190
#
# Epoch 01419: val_loss did not improve from 0.03190
#
# Epoch 01420: val_loss did not improve from 0.03190
#
# Epoch 01421: val_loss did not improve from 0.03190
#
# Epoch 01422: val_loss did not improve from 0.03190
#
# Epoch 01423: val_loss did not improve from 0.03190
#
# Epoch 01424: val_loss did not improve from 0.03190
#
# Epoch 01425: val_loss did not improve from 0.03190
#
# Epoch 01426: val_loss did not improve from 0.03190
# Epoch 01427: val_loss did not improve from 0.03190
#
# Epoch 01428: val_loss did not improve from 0.03190
#
# Epoch 01429: val_loss did not improve from 0.03190
#
# Epoch 01430: val_loss did not improve from 0.03190
#
# Epoch 01431: val_loss did not improve from 0.03190
#
# Epoch 01432: val_loss did not improve from 0.03190
#
# Epoch 01433: val_loss did not improve from 0.03190
#
# Epoch 01434: val_loss did not improve from 0.03190
#
# Epoch 01435: val_loss did not improve from 0.03190
