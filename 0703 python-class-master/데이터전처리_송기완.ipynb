# %% [markdown]
# # 연습문제
#
#   - 자유롭게 데이터 전처리 하기
#
# ex)
# - 컬럼명 변경하기
# - 날짜 데이터 파싱하기
# - 이상치 처리하기
# - 계절, 날씨를 text로 변경하기(예: 봄, 여름, 가을, 겨울)
# - 자전거 대여횟수를 카테고리화 하기(예: 매우 적음, 적음, 보통, 많음, 매우 많음)
# - atemp 값을 소수점 2자리까지 보여지도록 바꾸기

# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
# 읽어드릴 파일 경로 : /dataset/bike_sharing_demand_train.csv
filepath = "class-master/datasets/exercise/bike_sharing_demand_train.csv"
data = pd.read_csv(filepath)
data
# Out:
#                   datetime  season  holiday  workingday  weather   temp  \
# 0      2011-01-01 00:00:00       1        0           0        1   9.84
# 1      2011-01-01 01:00:00       1        0           0        1   9.02
# 2      2011-01-01 02:00:00       1        0           0        1   9.02
# 3      2011-01-01 03:00:00       1        0           0        1   9.84
# 4      2011-01-01 04:00:00       1        0           0        1   9.84
# ...                    ...     ...      ...         ...      ...    ...
# 10881  2012-12-19 19:00:00       4        0           1        1  15.58
# 10882  2012-12-19 20:00:00       4        0           1        1  14.76
# 10883  2012-12-19 21:00:00       4        0           1        1  13.94
# 10884  2012-12-19 22:00:00       4        0           1        1  13.94
# 10885  2012-12-19 23:00:00       4        0           1        1  13.12
#
#         atemp  humidity  windspeed  casual  registered  count
# ...

# %% [markdown]
# # 혹시 NA 값 없는지 확인 / 지우기

# %%
from numpy import nan as NA
data.dropna()
# Out:
#                   datetime  season  holiday  workingday  weather   temp  \
# 0      2011-01-01 00:00:00       1        0           0        1   9.84
# 1      2011-01-01 01:00:00       1        0           0        1   9.02
# 2      2011-01-01 02:00:00       1        0           0        1   9.02
# 3      2011-01-01 03:00:00       1        0           0        1   9.84
# 4      2011-01-01 04:00:00       1        0           0        1   9.84
# ...                    ...     ...      ...         ...      ...    ...
# 10881  2012-12-19 19:00:00       4        0           1        1  15.58
# 10882  2012-12-19 20:00:00       4        0           1        1  14.76
# 10883  2012-12-19 21:00:00       4        0           1        1  13.94
# 10884  2012-12-19 22:00:00       4        0           1        1  13.94
# 10885  2012-12-19 23:00:00       4        0           1        1  13.12
#
#         atemp  humidity  windspeed  casual  registered  count
# ...

# %% [markdown]
# # 중복된 값 있으면 지우기

# %%
data.drop_duplicates()
# Out:
#                   datetime  season  holiday  workingday  weather   temp  \
# 0      2011-01-01 00:00:00       1        0           0        1   9.84
# 1      2011-01-01 01:00:00       1        0           0        1   9.02
# 2      2011-01-01 02:00:00       1        0           0        1   9.02
# 3      2011-01-01 03:00:00       1        0           0        1   9.84
# 4      2011-01-01 04:00:00       1        0           0        1   9.84
# ...                    ...     ...      ...         ...      ...    ...
# 10881  2012-12-19 19:00:00       4        0           1        1  15.58
# 10882  2012-12-19 20:00:00       4        0           1        1  14.76
# 10883  2012-12-19 21:00:00       4        0           1        1  13.94
# 10884  2012-12-19 22:00:00       4        0           1        1  13.94
# 10885  2012-12-19 23:00:00       4        0           1        1  13.12
#
#         atemp  humidity  windspeed  casual  registered  count
# ...

# %% [markdown]
# # 이상치 제거하기

# %%
#종속변수(count) 의 distribution 확인
sns.distplot(data['count'], color = 'red')
plt.show()
#종속변수(count) 의 boxplot 확인
sns.boxplot(x='count', color = 'green', data = data)
plt.show()

# %% [markdown]
# # 그래프를 보면 우측에 이상치가 많이 분포되어 있는 것을 확인(high outliers)
#
# # 이상치 범위 구하기

# %%
Q1 = data['count'].quantile(0.25)
Q3 = data['count'].quantile(0.75)
IQR = Q3 - Q1
outliers = data[data['count']> Q3 + 1.5 * IQR]
validmax = Q3 + 1.5 * IQR

# %%
outliers
# Out:
#                   datetime  season  holiday  workingday  weather   temp  \
# 6611   2012-03-12 18:00:00       1        0           1        2  24.60
# 6634   2012-03-13 17:00:00       1        0           1        1  28.70
# 6635   2012-03-13 18:00:00       1        0           1        1  28.70
# 6649   2012-03-14 08:00:00       1        0           1        1  18.04
# 6658   2012-03-14 17:00:00       1        0           1        1  28.70
# ...                    ...     ...      ...         ...      ...    ...
# 10678  2012-12-11 08:00:00       4        0           1        2  13.94
# 10702  2012-12-12 08:00:00       4        0           1        2  10.66
# 10726  2012-12-13 08:00:00       4        0           1        1   9.84
# 10846  2012-12-18 08:00:00       4        0           1        1  15.58
# 10870  2012-12-19 08:00:00       4        0           1        1   9.84
#
#         atemp  humidity  windspeed  casual  registered  count
# ...

# %% [markdown]
# # 이상치를 data에서 제거하기

# %%
validmax
# Out:
# 647.0

# %%
#validmax가 647 이므로, 647 이상 값을 가지고 있는 행들을 데이터셋에서 제거
remout = data[data['count']> 647.0].index
newdata = data.drop(remout)
newdata
# Out:
#                   datetime  season  holiday  workingday  weather   temp  \
# 0      2011-01-01 00:00:00       1        0           0        1   9.84
# 1      2011-01-01 01:00:00       1        0           0        1   9.02
# 2      2011-01-01 02:00:00       1        0           0        1   9.02
# 3      2011-01-01 03:00:00       1        0           0        1   9.84
# 4      2011-01-01 04:00:00       1        0           0        1   9.84
# ...                    ...     ...      ...         ...      ...    ...
# 10881  2012-12-19 19:00:00       4        0           1        1  15.58
# 10882  2012-12-19 20:00:00       4        0           1        1  14.76
# 10883  2012-12-19 21:00:00       4        0           1        1  13.94
# 10884  2012-12-19 22:00:00       4        0           1        1  13.94
# 10885  2012-12-19 23:00:00       4        0           1        1  13.12
#
#         atemp  humidity  windspeed  casual  registered  count
# ...

# %% [markdown]
# # 계절을 숫자에서 텍스트로 변환하기

# %%
newdata['season'].replace({1:'봄', 2:'여름', 3:'가을', 4:'겨울'})
newdata
# Out:
#                   datetime  season  holiday  workingday  weather   temp  \
# 0      2011-01-01 00:00:00       1        0           0        1   9.84
# 1      2011-01-01 01:00:00       1        0           0        1   9.02
# 2      2011-01-01 02:00:00       1        0           0        1   9.02
# 3      2011-01-01 03:00:00       1        0           0        1   9.84
# 4      2011-01-01 04:00:00       1        0           0        1   9.84
# ...                    ...     ...      ...         ...      ...    ...
# 10881  2012-12-19 19:00:00       4        0           1        1  15.58
# 10882  2012-12-19 20:00:00       4        0           1        1  14.76
# 10883  2012-12-19 21:00:00       4        0           1        1  13.94
# 10884  2012-12-19 22:00:00       4        0           1        1  13.94
# 10885  2012-12-19 23:00:00       4        0           1        1  13.12
#
#         atemp  humidity  windspeed  casual  registered  count
# ...
